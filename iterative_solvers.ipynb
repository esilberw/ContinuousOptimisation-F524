# %%
# Install the 'proxop' library, which provides proximal operators for optimization algorithms.
# This command should be run in a Jupyter Notebook or Google Colab environment.
# The exclamation mark (!) is used to run shell commands from within Python notebooks.
# !pip install proxop
# Out:
# Requirement already satisfied: proxop in /usr/local/lib/python3.11/dist-packages (1.0.6)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from proxop) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from proxop) (1.15.3)

# %%
# Import necessary libraries
import numpy as np # For numerical operations
import pandas as pd  # For data manipulation using DataFrames
from sklearn import datasets # For loading standard datasets from scikit-learn
import time  # For measuring execution time

# Load the diabetes dataset
diabetes = datasets.load_diabetes()

# Print dataset description
print(diabetes.DESCR)

# Extract the feature matrix (inputs) from the dataset
X = diabetes.data # Shape: (442, 10)
# Extract the target vector
y= diabetes.target
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
# Replace NaNs in X with column means
col_means = np.nanmean(X, axis=0)
inds = np.where(np.isnan(X))
X[inds] = np.take(col_means, inds[1])

# Replace NaNs in y with mean
y = np.nan_to_num(y, nan=np.nanmean(y))

# Standardize features (recommended for gradient descent)
X_mean = np.mean(X, axis=0)
X_std = np.std(X, axis=0)
X = (X - X_mean) / X_std

# Add intercept term (bias)
X = np.c_[np.ones(X.shape[0]), X]

# %%
# Compute Lipschitz constant L = ||X||_2^2 / m
#Perform Singular Value Decomposition (SVD) on X
U, S, Vt = np.linalg.svd(X, full_matrices=False)
# The spectral norm is the largest singular value of X
spectral_norm = S[0]
# Compute Lipschitz constant: L = (spectral_norm)^2 / number of samples
L = (spectral_norm ** 2) / X.shape[0]
# Compute the step size
eta = 1 / L  # Step size

# %%
print(f"Lipschitz constant: {L}")
print(f"Step size: {1/L}")
# Out:
# Lipschitz constant: 4.024210750152778
# Step size: 0.24849593177048077

# %%
# Define the mean squared error (MSE) loss function
def loss(beta, X, y):
    """
    Computes the Mean Squared Error loss.

    Parameters:
    - beta: Coefficient vector (numpy array)
    - X: Feature matrix (numpy array)
    - y: Target vector

    Returns:
    - MSE loss value (float)
    """
    return np.mean((X @ beta - y) ** 2)


# Backtracking line search
def backtracking_line_search(X, y, beta, grad, L, t_init=1, alpha=0.9, c=1e-4):
    """
    Performs backtracking line search to find a suitable step size.

    Parameters:
    - X, y: Feature matrix and target vector
    - beta: Current parameter estimate
    - grad: Gradient of loss at beta
    - L: Lipschitz constant
    - t_init: Initial step size
    - alpha: Step size shrinkage factor (0 < alpha < 1)
    - c: Armijo condition constant (typically small, e.g. 1e-4)

    Returns:
    - t: Chosen step size
    """
    t_min = min(t_init, alpha / float(L)) # Prevent step size from shrinking too small
    t = t_min
    direction = -grad # Descent direction
    loss_old = loss(beta, X, y)
    # Line search loop
    while True:
        beta_new = beta + t * direction
        loss_new = loss(beta_new, X, y)
        # Armijo condition
        if loss_new <= loss_old + c * t * np.dot(grad, direction):
            break
        t *= alpha
        if t < t_min:
            t = t_min
            break
    return t

# Gradient Descent with Backtracking Line Search
def gradient_descent_backtracking_L(X, y, L, epsilon=1e-6):
    """
    Performs gradient descent using backtracking line search and a Lipschitz estimate.

    Parameters:
    - X, y: Feature matrix and target vector
    - L: Lipschitz constant
    - epsilon: Convergence tolerance

    Returns:
    - beta: Optimal parameter vector
    """
    n, d = X.shape # Initialize parameters
    beta = np.ones(d)
    t_init=1   # Initial step size
    i=0 # Iteration counter
    while(True):
        i+=1
        grad = (2 / n) * X.T @ (X @ beta - y) # Compute gradient
        beta_prev = beta.copy() # Store previous parameters
        # Backtracking line search to get step size
        eta = backtracking_line_search(X, y, beta, grad, L,t_init)
        t_init=eta  # Update initial step size for next iteration
        # Gradient descent step
        beta = beta_prev - eta * grad
        # Check relative change in loss for convergence
        if abs(loss(beta,X,y) - loss(beta_prev,X,y))/max(1,abs(loss(beta_prev,X,y))) < epsilon:
          print(f"Converged in {i} iterations.")
          break
        print(f"Iter {i+1}: step_size = {eta:.4e}")
    return beta
# Run optimization and measure computation time
start_time = time.time()
beta_opt = gradient_descent_backtracking_L(X, y, L)
end_time = time.time()
print(f"Obj: {loss(beta_opt,X,y)}")  # Final objective value
print(f"Running time= {end_time-start_time}") # Execution time
# Out:
# Iter 2: step_size = 2.2365e-01
# Iter 3: step_size = 2.2365e-01
# Iter 4: step_size = 2.2365e-01
# Iter 5: step_size = 2.2365e-01
# Iter 6: step_size = 2.2365e-01
# Iter 7: step_size = 2.2365e-01
# Iter 8: step_size = 2.2365e-01
# Iter 9: step_size = 2.2365e-01
# Iter 10: step_size = 2.2365e-01
# Iter 11: step_size = 2.2365e-01
# Iter 12: step_size = 2.2365e-01
# Iter 13: step_size = 2.2365e-01
# Iter 14: step_size = 2.2365e-01
# Iter 15: step_size = 2.2365e-01
# Iter 16: step_size = 2.2365e-01
# Iter 17: step_size = 2.2365e-01
# Iter 18: step_size = 2.2365e-01
# Iter 19: step_size = 2.2365e-01
# Iter 20: step_size = 2.2365e-01
# Iter 21: step_size = 2.2365e-01
# Iter 22: step_size = 2.2365e-01
# Iter 23: step_size = 2.2365e-01
# Iter 24: step_size = 2.2365e-01
# Iter 25: step_size = 2.2365e-01
# Iter 26: step_size = 2.2365e-01
# Iter 27: step_size = 2.2365e-01
# Iter 28: step_size = 2.2365e-01
# Iter 29: step_size = 2.2365e-01
# Iter 30: step_size = 2.2365e-01
# Iter 31: step_size = 2.2365e-01
# Iter 32: step_size = 2.2365e-01
# Iter 33: step_size = 2.2365e-01
# Iter 34: step_size = 2.2365e-01
# Iter 35: step_size = 2.2365e-01
# Iter 36: step_size = 2.2365e-01
# Iter 37: step_size = 2.2365e-01
# Iter 38: step_size = 2.2365e-01
# Iter 39: step_size = 2.2365e-01
# Iter 40: step_size = 2.2365e-01
# Iter 41: step_size = 2.2365e-01
# Iter 42: step_size = 2.2365e-01
# Iter 43: step_size = 2.2365e-01
# Iter 44: step_size = 2.2365e-01
# Iter 45: step_size = 2.2365e-01
# Iter 46: step_size = 2.2365e-01
# Iter 47: step_size = 2.2365e-01
# Iter 48: step_size = 2.2365e-01
# Iter 49: step_size = 2.2365e-01
# Iter 50: step_size = 2.2365e-01
# Iter 51: step_size = 2.2365e-01
# Iter 52: step_size = 2.2365e-01
# Iter 53: step_size = 2.2365e-01
# Iter 54: step_size = 2.2365e-01
# Iter 55: step_size = 2.2365e-01
# Iter 56: step_size = 2.2365e-01
# Iter 57: step_size = 2.2365e-01
# Iter 58: step_size = 2.2365e-01
# Iter 59: step_size = 2.2365e-01
# Iter 60: step_size = 2.2365e-01
# Iter 61: step_size = 2.2365e-01
# Iter 62: step_size = 2.2365e-01
# Iter 63: step_size = 2.2365e-01
# Iter 64: step_size = 2.2365e-01
# Iter 65: step_size = 2.2365e-01
# Iter 66: step_size = 2.2365e-01
# Iter 67: step_size = 2.2365e-01
# Iter 68: step_size = 2.2365e-01
# Iter 69: step_size = 2.2365e-01
# Iter 70: step_size = 2.2365e-01
# Iter 71: step_size = 2.2365e-01
# Iter 72: step_size = 2.2365e-01
# Iter 73: step_size = 2.2365e-01
# Iter 74: step_size = 2.2365e-01
# Iter 75: step_size = 2.2365e-01
# Iter 76: step_size = 2.2365e-01
# Iter 77: step_size = 2.2365e-01
# Iter 78: step_size = 2.2365e-01
# Iter 79: step_size = 2.2365e-01
# Iter 80: step_size = 2.2365e-01
# Iter 81: step_size = 2.2365e-01
# Iter 82: step_size = 2.2365e-01
# Iter 83: step_size = 2.2365e-01
# Iter 84: step_size = 2.2365e-01
# Iter 85: step_size = 2.2365e-01
# Iter 86: step_size = 2.2365e-01
# Iter 87: step_size = 2.2365e-01
# Iter 88: step_size = 2.2365e-01
# Iter 89: step_size = 2.2365e-01
# Iter 90: step_size = 2.2365e-01
# Iter 91: step_size = 2.2365e-01
# Iter 92: step_size = 2.2365e-01
# Iter 93: step_size = 2.2365e-01
# Iter 94: step_size = 2.2365e-01
# Iter 95: step_size = 2.2365e-01
# Iter 96: step_size = 2.2365e-01
# Iter 97: step_size = 2.2365e-01
# Iter 98: step_size = 2.2365e-01
# Iter 99: step_size = 2.2365e-01
# Iter 100: step_size = 2.2365e-01
# Iter 101: step_size = 2.2365e-01
# Iter 102: step_size = 2.2365e-01
# Iter 103: step_size = 2.2365e-01
# Iter 104: step_size = 2.2365e-01
# Iter 105: step_size = 2.2365e-01
# Iter 106: step_size = 2.2365e-01
# Iter 107: step_size = 2.2365e-01
# Iter 108: step_size = 2.2365e-01
# Iter 109: step_size = 2.2365e-01
# Iter 110: step_size = 2.2365e-01
# Iter 111: step_size = 2.2365e-01
# Iter 112: step_size = 2.2365e-01
# Iter 113: step_size = 2.2365e-01
# Iter 114: step_size = 2.2365e-01
# Iter 115: step_size = 2.2365e-01
# Iter 116: step_size = 2.2365e-01
# Iter 117: step_size = 2.2365e-01
# Iter 118: step_size = 2.2365e-01
# Iter 119: step_size = 2.2365e-01
# Iter 120: step_size = 2.2365e-01
# Iter 121: step_size = 2.2365e-01
# Iter 122: step_size = 2.2365e-01
# Iter 123: step_size = 2.2365e-01
# Iter 124: step_size = 2.2365e-01
# Iter 125: step_size = 2.2365e-01
# Iter 126: step_size = 2.2365e-01
# Iter 127: step_size = 2.2365e-01
# Iter 128: step_size = 2.2365e-01
# Iter 129: step_size = 2.2365e-01
# Iter 130: step_size = 2.2365e-01
# Iter 131: step_size = 2.2365e-01
# Iter 132: step_size = 2.2365e-01
# Iter 133: step_size = 2.2365e-01
# Iter 134: step_size = 2.2365e-01
# Iter 135: step_size = 2.2365e-01
# Iter 136: step_size = 2.2365e-01
# Iter 137: step_size = 2.2365e-01
# Iter 138: step_size = 2.2365e-01
# Iter 139: step_size = 2.2365e-01
# Iter 140: step_size = 2.2365e-01
# Iter 141: step_size = 2.2365e-01
# Iter 142: step_size = 2.2365e-01
# Iter 143: step_size = 2.2365e-01
# Iter 144: step_size = 2.2365e-01
# Iter 145: step_size = 2.2365e-01
# Iter 146: step_size = 2.2365e-01
# Iter 147: step_size = 2.2365e-01
# Iter 148: step_size = 2.2365e-01
# Iter 149: step_size = 2.2365e-01
# Iter 150: step_size = 2.2365e-01
# Iter 151: step_size = 2.2365e-01
# Iter 152: step_size = 2.2365e-01
# Iter 153: step_size = 2.2365e-01
# Iter 154: step_size = 2.2365e-01
# Iter 155: step_size = 2.2365e-01
# Iter 156: step_size = 2.2365e-01
# Iter 157: step_size = 2.2365e-01
# Iter 158: step_size = 2.2365e-01
# Iter 159: step_size = 2.2365e-01
# Iter 160: step_size = 2.2365e-01
# Iter 161: step_size = 2.2365e-01
# Iter 162: step_size = 2.2365e-01
# Iter 163: step_size = 2.2365e-01
# Iter 164: step_size = 2.2365e-01
# Iter 165: step_size = 2.2365e-01
# Iter 166: step_size = 2.2365e-01
# Iter 167: step_size = 2.2365e-01
# Iter 168: step_size = 2.2365e-01
# Iter 169: step_size = 2.2365e-01
# Iter 170: step_size = 2.2365e-01
# Iter 171: step_size = 2.2365e-01
# Iter 172: step_size = 2.2365e-01
# Iter 173: step_size = 2.2365e-01
# Iter 174: step_size = 2.2365e-01
# Iter 175: step_size = 2.2365e-01
# Iter 176: step_size = 2.2365e-01
# Iter 177: step_size = 2.2365e-01
# Iter 178: step_size = 2.2365e-01
# Iter 179: step_size = 2.2365e-01
# Iter 180: step_size = 2.2365e-01
# Iter 181: step_size = 2.2365e-01
# Iter 182: step_size = 2.2365e-01
# Iter 183: step_size = 2.2365e-01
# Iter 184: step_size = 2.2365e-01
# Iter 185: step_size = 2.2365e-01
# Iter 186: step_size = 2.2365e-01
# Iter 187: step_size = 2.2365e-01
# Iter 188: step_size = 2.2365e-01
# Iter 189: step_size = 2.2365e-01
# Iter 190: step_size = 2.2365e-01
# Iter 191: step_size = 2.2365e-01
# Iter 192: step_size = 2.2365e-01
# Iter 193: step_size = 2.2365e-01
# Iter 194: step_size = 2.2365e-01
# Iter 195: step_size = 2.2365e-01
# Iter 196: step_size = 2.2365e-01
# Iter 197: step_size = 2.2365e-01
# Iter 198: step_size = 2.2365e-01
# Iter 199: step_size = 2.2365e-01
# Iter 200: step_size = 2.2365e-01
# Iter 201: step_size = 2.2365e-01
# Iter 202: step_size = 2.2365e-01
# Iter 203: step_size = 2.2365e-01
# Iter 204: step_size = 2.2365e-01
# Iter 205: step_size = 2.2365e-01
# Iter 206: step_size = 2.2365e-01
# Iter 207: step_size = 2.2365e-01
# Iter 208: step_size = 2.2365e-01
# Iter 209: step_size = 2.2365e-01
# Iter 210: step_size = 2.2365e-01
# Iter 211: step_size = 2.2365e-01
# Iter 212: step_size = 2.2365e-01
# Iter 213: step_size = 2.2365e-01
# Iter 214: step_size = 2.2365e-01
# Iter 215: step_size = 2.2365e-01
# Iter 216: step_size = 2.2365e-01
# Iter 217: step_size = 2.2365e-01
# Iter 218: step_size = 2.2365e-01
# Iter 219: step_size = 2.2365e-01
# Iter 220: step_size = 2.2365e-01
# Iter 221: step_size = 2.2365e-01
# Iter 222: step_size = 2.2365e-01
# Iter 223: step_size = 2.2365e-01
# Iter 224: step_size = 2.2365e-01
# Iter 225: step_size = 2.2365e-01
# Iter 226: step_size = 2.2365e-01
# Iter 227: step_size = 2.2365e-01
# Iter 228: step_size = 2.2365e-01
# Iter 229: step_size = 2.2365e-01
# Iter 230: step_size = 2.2365e-01
# Iter 231: step_size = 2.2365e-01
# Iter 232: step_size = 2.2365e-01
# Iter 233: step_size = 2.2365e-01
# Iter 234: step_size = 2.2365e-01
# Iter 235: step_size = 2.2365e-01
# Iter 236: step_size = 2.2365e-01
# Iter 237: step_size = 2.2365e-01
# Iter 238: step_size = 2.2365e-01
# Iter 239: step_size = 2.2365e-01
# Iter 240: step_size = 2.2365e-01
# Iter 241: step_size = 2.2365e-01
# Iter 242: step_size = 2.2365e-01
# Iter 243: step_size = 2.2365e-01
# Iter 244: step_size = 2.2365e-01
# Iter 245: step_size = 2.2365e-01
# Iter 246: step_size = 2.2365e-01
# Iter 247: step_size = 2.2365e-01
# Iter 248: step_size = 2.2365e-01
# Iter 249: step_size = 2.2365e-01
# Iter 250: step_size = 2.2365e-01
# Iter 251: step_size = 2.2365e-01
# Iter 252: step_size = 2.2365e-01
# Iter 253: step_size = 2.2365e-01
# Iter 254: step_size = 2.2365e-01
# Iter 255: step_size = 2.2365e-01
# Iter 256: step_size = 2.2365e-01
# Iter 257: step_size = 2.2365e-01
# Iter 258: step_size = 2.2365e-01
# Iter 259: step_size = 2.2365e-01
# Iter 260: step_size = 2.2365e-01
# Iter 261: step_size = 2.2365e-01
# Iter 262: step_size = 2.2365e-01
# Iter 263: step_size = 2.2365e-01
# Iter 264: step_size = 2.2365e-01
# Iter 265: step_size = 2.2365e-01
# Iter 266: step_size = 2.2365e-01
# Iter 267: step_size = 2.2365e-01
# Iter 268: step_size = 2.2365e-01
# Iter 269: step_size = 2.2365e-01
# Iter 270: step_size = 2.2365e-01
# Iter 271: step_size = 2.2365e-01
# Iter 272: step_size = 2.2365e-01
# Iter 273: step_size = 2.2365e-01
# Iter 274: step_size = 2.2365e-01
# Iter 275: step_size = 2.2365e-01
# Iter 276: step_size = 2.2365e-01
# Iter 277: step_size = 2.2365e-01
# Iter 278: step_size = 2.2365e-01
# Iter 279: step_size = 2.2365e-01
# Iter 280: step_size = 2.2365e-01
# Iter 281: step_size = 2.2365e-01
# Iter 282: step_size = 2.2365e-01
# Iter 283: step_size = 2.2365e-01
# Iter 284: step_size = 2.2365e-01
# Iter 285: step_size = 2.2365e-01
# Iter 286: step_size = 2.2365e-01
# Iter 287: step_size = 2.2365e-01
# Iter 288: step_size = 2.2365e-01
# Iter 289: step_size = 2.2365e-01
# Iter 290: step_size = 2.2365e-01
# Iter 291: step_size = 2.2365e-01
# Iter 292: step_size = 2.2365e-01
# Iter 293: step_size = 2.2365e-01
# Iter 294: step_size = 2.2365e-01
# Iter 295: step_size = 2.2365e-01
# Iter 296: step_size = 2.2365e-01
# Iter 297: step_size = 2.2365e-01
# Iter 298: step_size = 2.2365e-01
# Iter 299: step_size = 2.2365e-01
# Iter 300: step_size = 2.2365e-01
# Iter 301: step_size = 2.2365e-01
# Iter 302: step_size = 2.2365e-01
# Iter 303: step_size = 2.2365e-01
# Iter 304: step_size = 2.2365e-01
# Iter 305: step_size = 2.2365e-01
# Iter 306: step_size = 2.2365e-01
# Iter 307: step_size = 2.2365e-01
# Iter 308: step_size = 2.2365e-01
# Iter 309: step_size = 2.2365e-01
# Iter 310: step_size = 2.2365e-01
# Iter 311: step_size = 2.2365e-01
# Iter 312: step_size = 2.2365e-01
# Iter 313: step_size = 2.2365e-01
# Iter 314: step_size = 2.2365e-01
# Iter 315: step_size = 2.2365e-01
# Iter 316: step_size = 2.2365e-01
# Iter 317: step_size = 2.2365e-01
# Iter 318: step_size = 2.2365e-01
# Iter 319: step_size = 2.2365e-01
# Iter 320: step_size = 2.2365e-01
# Iter 321: step_size = 2.2365e-01
# Iter 322: step_size = 2.2365e-01
# Iter 323: step_size = 2.2365e-01
# Iter 324: step_size = 2.2365e-01
# Iter 325: step_size = 2.2365e-01
# Iter 326: step_size = 2.2365e-01
# Iter 327: step_size = 2.2365e-01
# Iter 328: step_size = 2.2365e-01
# Iter 329: step_size = 2.2365e-01
# Iter 330: step_size = 2.2365e-01
# Iter 331: step_size = 2.2365e-01
# Iter 332: step_size = 2.2365e-01
# Iter 333: step_size = 2.2365e-01
# Iter 334: step_size = 2.2365e-01
# Iter 335: step_size = 2.2365e-01
# Iter 336: step_size = 2.2365e-01
# Iter 337: step_size = 2.2365e-01
# Iter 338: step_size = 2.2365e-01
# Iter 339: step_size = 2.2365e-01
# Iter 340: step_size = 2.2365e-01
# Iter 341: step_size = 2.2365e-01
# Iter 342: step_size = 2.2365e-01
# Iter 343: step_size = 2.2365e-01
# Iter 344: step_size = 2.2365e-01
# Iter 345: step_size = 2.2365e-01
# Iter 346: step_size = 2.2365e-01
# Iter 347: step_size = 2.2365e-01
# Iter 348: step_size = 2.2365e-01
# Iter 349: step_size = 2.2365e-01
# Iter 350: step_size = 2.2365e-01
# Iter 351: step_size = 2.2365e-01
# Iter 352: step_size = 2.2365e-01
# Iter 353: step_size = 2.2365e-01
# Iter 354: step_size = 2.2365e-01
# Iter 355: step_size = 2.2365e-01
# Iter 356: step_size = 2.2365e-01
# Iter 357: step_size = 2.2365e-01
# Iter 358: step_size = 2.2365e-01
# Iter 359: step_size = 2.2365e-01
# Iter 360: step_size = 2.2365e-01
# Iter 361: step_size = 2.2365e-01
# Iter 362: step_size = 2.2365e-01
# Iter 363: step_size = 2.2365e-01
# Iter 364: step_size = 2.2365e-01
# Iter 365: step_size = 2.2365e-01
# Iter 366: step_size = 2.2365e-01
# Iter 367: step_size = 2.2365e-01
# Iter 368: step_size = 2.2365e-01
# Iter 369: step_size = 2.2365e-01
# Iter 370: step_size = 2.2365e-01
# Iter 371: step_size = 2.2365e-01
# Iter 372: step_size = 2.2365e-01
# Iter 373: step_size = 2.2365e-01
# Iter 374: step_size = 2.2365e-01
# Iter 375: step_size = 2.2365e-01
# Iter 376: step_size = 2.2365e-01
# Iter 377: step_size = 2.2365e-01
# Iter 378: step_size = 2.2365e-01
# Iter 379: step_size = 2.2365e-01
# Iter 380: step_size = 2.2365e-01
# Iter 381: step_size = 2.2365e-01
# Iter 382: step_size = 2.2365e-01
# Iter 383: step_size = 2.2365e-01
# Iter 384: step_size = 2.2365e-01
# Iter 385: step_size = 2.2365e-01
# Iter 386: step_size = 2.2365e-01
# Iter 387: step_size = 2.2365e-01
# Iter 388: step_size = 2.2365e-01
# Iter 389: step_size = 2.2365e-01
# Iter 390: step_size = 2.2365e-01
# Iter 391: step_size = 2.2365e-01
# Iter 392: step_size = 2.2365e-01
# Iter 393: step_size = 2.2365e-01
# Iter 394: step_size = 2.2365e-01
# Iter 395: step_size = 2.2365e-01
# Iter 396: step_size = 2.2365e-01
# Iter 397: step_size = 2.2365e-01
# Iter 398: step_size = 2.2365e-01
# Iter 399: step_size = 2.2365e-01
# Iter 400: step_size = 2.2365e-01
# Iter 401: step_size = 2.2365e-01
# Iter 402: step_size = 2.2365e-01
# Iter 403: step_size = 2.2365e-01
# Iter 404: step_size = 2.2365e-01
# Iter 405: step_size = 2.2365e-01
# Iter 406: step_size = 2.2365e-01
# Iter 407: step_size = 2.2365e-01
# Iter 408: step_size = 2.2365e-01
# Iter 409: step_size = 2.2365e-01
# Iter 410: step_size = 2.2365e-01
# Iter 411: step_size = 2.2365e-01
# Iter 412: step_size = 2.2365e-01
# Iter 413: step_size = 2.2365e-01
# Iter 414: step_size = 2.2365e-01
# Iter 415: step_size = 2.2365e-01
# Iter 416: step_size = 2.2365e-01
# Iter 417: step_size = 2.2365e-01
# Iter 418: step_size = 2.2365e-01
# Iter 419: step_size = 2.2365e-01
# Iter 420: step_size = 2.2365e-01
# Iter 421: step_size = 2.2365e-01
# Iter 422: step_size = 2.2365e-01
# Iter 423: step_size = 2.2365e-01
# Iter 424: step_size = 2.2365e-01
# Iter 425: step_size = 2.2365e-01
# Iter 426: step_size = 2.2365e-01
# Iter 427: step_size = 2.2365e-01
# Iter 428: step_size = 2.2365e-01
# Iter 429: step_size = 2.2365e-01
# Iter 430: step_size = 2.2365e-01
# Iter 431: step_size = 2.2365e-01
# Iter 432: step_size = 2.2365e-01
# Iter 433: step_size = 2.2365e-01
# Iter 434: step_size = 2.2365e-01
# Iter 435: step_size = 2.2365e-01
# Iter 436: step_size = 2.2365e-01
# Iter 437: step_size = 2.2365e-01
# Iter 438: step_size = 2.2365e-01
# Iter 439: step_size = 2.2365e-01
# Iter 440: step_size = 2.2365e-01
# Iter 441: step_size = 2.2365e-01
# Iter 442: step_size = 2.2365e-01
# Iter 443: step_size = 2.2365e-01
# Iter 444: step_size = 2.2365e-01
# Iter 445: step_size = 2.2365e-01
# Iter 446: step_size = 2.2365e-01
# Iter 447: step_size = 2.2365e-01
# Iter 448: step_size = 2.2365e-01
# Iter 449: step_size = 2.2365e-01
# Iter 450: step_size = 2.2365e-01
# Iter 451: step_size = 2.2365e-01
# Iter 452: step_size = 2.2365e-01
# Iter 453: step_size = 2.2365e-01
# Iter 454: step_size = 2.2365e-01
# Iter 455: step_size = 2.2365e-01
# Iter 456: step_size = 2.2365e-01
# Iter 457: step_size = 2.2365e-01
# Iter 458: step_size = 2.2365e-01
# Iter 459: step_size = 2.2365e-01
# Iter 460: step_size = 2.2365e-01
# Iter 461: step_size = 2.2365e-01
# Iter 462: step_size = 2.2365e-01
# Iter 463: step_size = 2.2365e-01
# Iter 464: step_size = 2.2365e-01
# Iter 465: step_size = 2.2365e-01
# Iter 466: step_size = 2.2365e-01
# Iter 467: step_size = 2.2365e-01
# Iter 468: step_size = 2.2365e-01
# Iter 469: step_size = 2.2365e-01
# Iter 470: step_size = 2.2365e-01
# Iter 471: step_size = 2.2365e-01
# Iter 472: step_size = 2.2365e-01
# Iter 473: step_size = 2.2365e-01
# Iter 474: step_size = 2.2365e-01
# Iter 475: step_size = 2.2365e-01
# Iter 476: step_size = 2.2365e-01
# Iter 477: step_size = 2.2365e-01
# Iter 478: step_size = 2.2365e-01
# Iter 479: step_size = 2.2365e-01
# Iter 480: step_size = 2.2365e-01
# Iter 481: step_size = 2.2365e-01
# Iter 482: step_size = 2.2365e-01
# Iter 483: step_size = 2.2365e-01
# Iter 484: step_size = 2.2365e-01
# Iter 485: step_size = 2.2365e-01
# Iter 486: step_size = 2.2365e-01
# Iter 487: step_size = 2.2365e-01
# Iter 488: step_size = 2.2365e-01
# Iter 489: step_size = 2.2365e-01
# Iter 490: step_size = 2.2365e-01
# Iter 491: step_size = 2.2365e-01
# Iter 492: step_size = 2.2365e-01
# Iter 493: step_size = 2.2365e-01
# Iter 494: step_size = 2.2365e-01
# Iter 495: step_size = 2.2365e-01
# Iter 496: step_size = 2.2365e-01
# Iter 497: step_size = 2.2365e-01
# Iter 498: step_size = 2.2365e-01
# Iter 499: step_size = 2.2365e-01
# Iter 500: step_size = 2.2365e-01
# Iter 501: step_size = 2.2365e-01
# Iter 502: step_size = 2.2365e-01
# Iter 503: step_size = 2.2365e-01
# Iter 504: step_size = 2.2365e-01
# Iter 505: step_size = 2.2365e-01
# Iter 506: step_size = 2.2365e-01
# Iter 507: step_size = 2.2365e-01
# Iter 508: step_size = 2.2365e-01
# Iter 509: step_size = 2.2365e-01
# Iter 510: step_size = 2.2365e-01
# Iter 511: step_size = 2.2365e-01
# Iter 512: step_size = 2.2365e-01
# Iter 513: step_size = 2.2365e-01
# Iter 514: step_size = 2.2365e-01
# Iter 515: step_size = 2.2365e-01
# Iter 516: step_size = 2.2365e-01
# Iter 517: step_size = 2.2365e-01
# Iter 518: step_size = 2.2365e-01
# Iter 519: step_size = 2.2365e-01
# Iter 520: step_size = 2.2365e-01
# Iter 521: step_size = 2.2365e-01
# Iter 522: step_size = 2.2365e-01
# Iter 523: step_size = 2.2365e-01
# Iter 524: step_size = 2.2365e-01
# Iter 525: step_size = 2.2365e-01
# Iter 526: step_size = 2.2365e-01
# Iter 527: step_size = 2.2365e-01
# Iter 528: step_size = 2.2365e-01
# Iter 529: step_size = 2.2365e-01
# Iter 530: step_size = 2.2365e-01
# Iter 531: step_size = 2.2365e-01
# Iter 532: step_size = 2.2365e-01
# Converged in 532 iterations.
# Obj: 2860.0665306673345
# Running time= 0.20269012451171875

# %%
# Gradient descent Fixed step size
def gradient_descent_L(X, y, L, epsilon=1e-6):
    n, d = X.shape
    beta = np.ones(d)
    step_size=1/L
    i=0
    while(True):
        i+=1
        grad = (2 / n) * X.T @ (X @ beta - y)
        beta_prev = beta.copy()
        beta = beta_prev - step_size * grad
        if abs(loss(beta,X,y) - loss(beta_prev,X,y))/max(1,abs(loss(beta_prev,X,y))) < epsilon:
          print(f"Converged in {i} iterations.")
          break
        print(f"Iter {i+1}: step_size = {step_size:.4e}")
    return beta
start_time = time.time()
beta_opt = gradient_descent_backtracking_L(X, y, L)
end_time = time.time()
print(f"Obj: {loss(beta_opt,X,y)}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 2: step_size = 2.2365e-01
# Iter 3: step_size = 2.2365e-01
# Iter 4: step_size = 2.2365e-01
# Iter 5: step_size = 2.2365e-01
# Iter 6: step_size = 2.2365e-01
# Iter 7: step_size = 2.2365e-01
# Iter 8: step_size = 2.2365e-01
# Iter 9: step_size = 2.2365e-01
# Iter 10: step_size = 2.2365e-01
# Iter 11: step_size = 2.2365e-01
# Iter 12: step_size = 2.2365e-01
# Iter 13: step_size = 2.2365e-01
# Iter 14: step_size = 2.2365e-01
# Iter 15: step_size = 2.2365e-01
# Iter 16: step_size = 2.2365e-01
# Iter 17: step_size = 2.2365e-01
# Iter 18: step_size = 2.2365e-01
# Iter 19: step_size = 2.2365e-01
# Iter 20: step_size = 2.2365e-01
# Iter 21: step_size = 2.2365e-01
# Iter 22: step_size = 2.2365e-01
# Iter 23: step_size = 2.2365e-01
# Iter 24: step_size = 2.2365e-01
# Iter 25: step_size = 2.2365e-01
# Iter 26: step_size = 2.2365e-01
# Iter 27: step_size = 2.2365e-01
# Iter 28: step_size = 2.2365e-01
# Iter 29: step_size = 2.2365e-01
# Iter 30: step_size = 2.2365e-01
# Iter 31: step_size = 2.2365e-01
# Iter 32: step_size = 2.2365e-01
# Iter 33: step_size = 2.2365e-01
# Iter 34: step_size = 2.2365e-01
# Iter 35: step_size = 2.2365e-01
# Iter 36: step_size = 2.2365e-01
# Iter 37: step_size = 2.2365e-01
# Iter 38: step_size = 2.2365e-01
# Iter 39: step_size = 2.2365e-01
# Iter 40: step_size = 2.2365e-01
# Iter 41: step_size = 2.2365e-01
# Iter 42: step_size = 2.2365e-01
# Iter 43: step_size = 2.2365e-01
# Iter 44: step_size = 2.2365e-01
# Iter 45: step_size = 2.2365e-01
# Iter 46: step_size = 2.2365e-01
# Iter 47: step_size = 2.2365e-01
# Iter 48: step_size = 2.2365e-01
# Iter 49: step_size = 2.2365e-01
# Iter 50: step_size = 2.2365e-01
# Iter 51: step_size = 2.2365e-01
# Iter 52: step_size = 2.2365e-01
# Iter 53: step_size = 2.2365e-01
# Iter 54: step_size = 2.2365e-01
# Iter 55: step_size = 2.2365e-01
# Iter 56: step_size = 2.2365e-01
# Iter 57: step_size = 2.2365e-01
# Iter 58: step_size = 2.2365e-01
# Iter 59: step_size = 2.2365e-01
# Iter 60: step_size = 2.2365e-01
# Iter 61: step_size = 2.2365e-01
# Iter 62: step_size = 2.2365e-01
# Iter 63: step_size = 2.2365e-01
# Iter 64: step_size = 2.2365e-01
# Iter 65: step_size = 2.2365e-01
# Iter 66: step_size = 2.2365e-01
# Iter 67: step_size = 2.2365e-01
# Iter 68: step_size = 2.2365e-01
# Iter 69: step_size = 2.2365e-01
# Iter 70: step_size = 2.2365e-01
# Iter 71: step_size = 2.2365e-01
# Iter 72: step_size = 2.2365e-01
# Iter 73: step_size = 2.2365e-01
# Iter 74: step_size = 2.2365e-01
# Iter 75: step_size = 2.2365e-01
# Iter 76: step_size = 2.2365e-01
# Iter 77: step_size = 2.2365e-01
# Iter 78: step_size = 2.2365e-01
# Iter 79: step_size = 2.2365e-01
# Iter 80: step_size = 2.2365e-01
# Iter 81: step_size = 2.2365e-01
# Iter 82: step_size = 2.2365e-01
# Iter 83: step_size = 2.2365e-01
# Iter 84: step_size = 2.2365e-01
# Iter 85: step_size = 2.2365e-01
# Iter 86: step_size = 2.2365e-01
# Iter 87: step_size = 2.2365e-01
# Iter 88: step_size = 2.2365e-01
# Iter 89: step_size = 2.2365e-01
# Iter 90: step_size = 2.2365e-01
# Iter 91: step_size = 2.2365e-01
# Iter 92: step_size = 2.2365e-01
# Iter 93: step_size = 2.2365e-01
# Iter 94: step_size = 2.2365e-01
# Iter 95: step_size = 2.2365e-01
# Iter 96: step_size = 2.2365e-01
# Iter 97: step_size = 2.2365e-01
# Iter 98: step_size = 2.2365e-01
# Iter 99: step_size = 2.2365e-01
# Iter 100: step_size = 2.2365e-01
# Iter 101: step_size = 2.2365e-01
# Iter 102: step_size = 2.2365e-01
# Iter 103: step_size = 2.2365e-01
# Iter 104: step_size = 2.2365e-01
# Iter 105: step_size = 2.2365e-01
# Iter 106: step_size = 2.2365e-01
# Iter 107: step_size = 2.2365e-01
# Iter 108: step_size = 2.2365e-01
# Iter 109: step_size = 2.2365e-01
# Iter 110: step_size = 2.2365e-01
# Iter 111: step_size = 2.2365e-01
# Iter 112: step_size = 2.2365e-01
# Iter 113: step_size = 2.2365e-01
# Iter 114: step_size = 2.2365e-01
# Iter 115: step_size = 2.2365e-01
# Iter 116: step_size = 2.2365e-01
# Iter 117: step_size = 2.2365e-01
# Iter 118: step_size = 2.2365e-01
# Iter 119: step_size = 2.2365e-01
# Iter 120: step_size = 2.2365e-01
# Iter 121: step_size = 2.2365e-01
# Iter 122: step_size = 2.2365e-01
# Iter 123: step_size = 2.2365e-01
# Iter 124: step_size = 2.2365e-01
# Iter 125: step_size = 2.2365e-01
# Iter 126: step_size = 2.2365e-01
# Iter 127: step_size = 2.2365e-01
# Iter 128: step_size = 2.2365e-01
# Iter 129: step_size = 2.2365e-01
# Iter 130: step_size = 2.2365e-01
# Iter 131: step_size = 2.2365e-01
# Iter 132: step_size = 2.2365e-01
# Iter 133: step_size = 2.2365e-01
# Iter 134: step_size = 2.2365e-01
# Iter 135: step_size = 2.2365e-01
# Iter 136: step_size = 2.2365e-01
# Iter 137: step_size = 2.2365e-01
# Iter 138: step_size = 2.2365e-01
# Iter 139: step_size = 2.2365e-01
# Iter 140: step_size = 2.2365e-01
# Iter 141: step_size = 2.2365e-01
# Iter 142: step_size = 2.2365e-01
# Iter 143: step_size = 2.2365e-01
# Iter 144: step_size = 2.2365e-01
# Iter 145: step_size = 2.2365e-01
# Iter 146: step_size = 2.2365e-01
# Iter 147: step_size = 2.2365e-01
# Iter 148: step_size = 2.2365e-01
# Iter 149: step_size = 2.2365e-01
# Iter 150: step_size = 2.2365e-01
# Iter 151: step_size = 2.2365e-01
# Iter 152: step_size = 2.2365e-01
# Iter 153: step_size = 2.2365e-01
# Iter 154: step_size = 2.2365e-01
# Iter 155: step_size = 2.2365e-01
# Iter 156: step_size = 2.2365e-01
# Iter 157: step_size = 2.2365e-01
# Iter 158: step_size = 2.2365e-01
# Iter 159: step_size = 2.2365e-01
# Iter 160: step_size = 2.2365e-01
# Iter 161: step_size = 2.2365e-01
# Iter 162: step_size = 2.2365e-01
# Iter 163: step_size = 2.2365e-01
# Iter 164: step_size = 2.2365e-01
# Iter 165: step_size = 2.2365e-01
# Iter 166: step_size = 2.2365e-01
# Iter 167: step_size = 2.2365e-01
# Iter 168: step_size = 2.2365e-01
# Iter 169: step_size = 2.2365e-01
# Iter 170: step_size = 2.2365e-01
# Iter 171: step_size = 2.2365e-01
# Iter 172: step_size = 2.2365e-01
# Iter 173: step_size = 2.2365e-01
# Iter 174: step_size = 2.2365e-01
# Iter 175: step_size = 2.2365e-01
# Iter 176: step_size = 2.2365e-01
# Iter 177: step_size = 2.2365e-01
# Iter 178: step_size = 2.2365e-01
# Iter 179: step_size = 2.2365e-01
# Iter 180: step_size = 2.2365e-01
# Iter 181: step_size = 2.2365e-01
# Iter 182: step_size = 2.2365e-01
# Iter 183: step_size = 2.2365e-01
# Iter 184: step_size = 2.2365e-01
# Iter 185: step_size = 2.2365e-01
# Iter 186: step_size = 2.2365e-01
# Iter 187: step_size = 2.2365e-01
# Iter 188: step_size = 2.2365e-01
# Iter 189: step_size = 2.2365e-01
# Iter 190: step_size = 2.2365e-01
# Iter 191: step_size = 2.2365e-01
# Iter 192: step_size = 2.2365e-01
# Iter 193: step_size = 2.2365e-01
# Iter 194: step_size = 2.2365e-01
# Iter 195: step_size = 2.2365e-01
# Iter 196: step_size = 2.2365e-01
# Iter 197: step_size = 2.2365e-01
# Iter 198: step_size = 2.2365e-01
# Iter 199: step_size = 2.2365e-01
# Iter 200: step_size = 2.2365e-01
# Iter 201: step_size = 2.2365e-01
# Iter 202: step_size = 2.2365e-01
# Iter 203: step_size = 2.2365e-01
# Iter 204: step_size = 2.2365e-01
# Iter 205: step_size = 2.2365e-01
# Iter 206: step_size = 2.2365e-01
# Iter 207: step_size = 2.2365e-01
# Iter 208: step_size = 2.2365e-01
# Iter 209: step_size = 2.2365e-01
# Iter 210: step_size = 2.2365e-01
# Iter 211: step_size = 2.2365e-01
# Iter 212: step_size = 2.2365e-01
# Iter 213: step_size = 2.2365e-01
# Iter 214: step_size = 2.2365e-01
# Iter 215: step_size = 2.2365e-01
# Iter 216: step_size = 2.2365e-01
# Iter 217: step_size = 2.2365e-01
# Iter 218: step_size = 2.2365e-01
# Iter 219: step_size = 2.2365e-01
# Iter 220: step_size = 2.2365e-01
# Iter 221: step_size = 2.2365e-01
# Iter 222: step_size = 2.2365e-01
# Iter 223: step_size = 2.2365e-01
# Iter 224: step_size = 2.2365e-01
# Iter 225: step_size = 2.2365e-01
# Iter 226: step_size = 2.2365e-01
# Iter 227: step_size = 2.2365e-01
# Iter 228: step_size = 2.2365e-01
# Iter 229: step_size = 2.2365e-01
# Iter 230: step_size = 2.2365e-01
# Iter 231: step_size = 2.2365e-01
# Iter 232: step_size = 2.2365e-01
# Iter 233: step_size = 2.2365e-01
# Iter 234: step_size = 2.2365e-01
# Iter 235: step_size = 2.2365e-01
# Iter 236: step_size = 2.2365e-01
# Iter 237: step_size = 2.2365e-01
# Iter 238: step_size = 2.2365e-01
# Iter 239: step_size = 2.2365e-01
# Iter 240: step_size = 2.2365e-01
# Iter 241: step_size = 2.2365e-01
# Iter 242: step_size = 2.2365e-01
# Iter 243: step_size = 2.2365e-01
# Iter 244: step_size = 2.2365e-01
# Iter 245: step_size = 2.2365e-01
# Iter 246: step_size = 2.2365e-01
# Iter 247: step_size = 2.2365e-01
# Iter 248: step_size = 2.2365e-01
# Iter 249: step_size = 2.2365e-01
# Iter 250: step_size = 2.2365e-01
# Iter 251: step_size = 2.2365e-01
# Iter 252: step_size = 2.2365e-01
# Iter 253: step_size = 2.2365e-01
# Iter 254: step_size = 2.2365e-01
# Iter 255: step_size = 2.2365e-01
# Iter 256: step_size = 2.2365e-01
# Iter 257: step_size = 2.2365e-01
# Iter 258: step_size = 2.2365e-01
# Iter 259: step_size = 2.2365e-01
# Iter 260: step_size = 2.2365e-01
# Iter 261: step_size = 2.2365e-01
# Iter 262: step_size = 2.2365e-01
# Iter 263: step_size = 2.2365e-01
# Iter 264: step_size = 2.2365e-01
# Iter 265: step_size = 2.2365e-01
# Iter 266: step_size = 2.2365e-01
# Iter 267: step_size = 2.2365e-01
# Iter 268: step_size = 2.2365e-01
# Iter 269: step_size = 2.2365e-01
# Iter 270: step_size = 2.2365e-01
# Iter 271: step_size = 2.2365e-01
# Iter 272: step_size = 2.2365e-01
# Iter 273: step_size = 2.2365e-01
# Iter 274: step_size = 2.2365e-01
# Iter 275: step_size = 2.2365e-01
# Iter 276: step_size = 2.2365e-01
# Iter 277: step_size = 2.2365e-01
# Iter 278: step_size = 2.2365e-01
# Iter 279: step_size = 2.2365e-01
# Iter 280: step_size = 2.2365e-01
# Iter 281: step_size = 2.2365e-01
# Iter 282: step_size = 2.2365e-01
# Iter 283: step_size = 2.2365e-01
# Iter 284: step_size = 2.2365e-01
# Iter 285: step_size = 2.2365e-01
# Iter 286: step_size = 2.2365e-01
# Iter 287: step_size = 2.2365e-01
# Iter 288: step_size = 2.2365e-01
# Iter 289: step_size = 2.2365e-01
# Iter 290: step_size = 2.2365e-01
# Iter 291: step_size = 2.2365e-01
# Iter 292: step_size = 2.2365e-01
# Iter 293: step_size = 2.2365e-01
# Iter 294: step_size = 2.2365e-01
# Iter 295: step_size = 2.2365e-01
# Iter 296: step_size = 2.2365e-01
# Iter 297: step_size = 2.2365e-01
# Iter 298: step_size = 2.2365e-01
# Iter 299: step_size = 2.2365e-01
# Iter 300: step_size = 2.2365e-01
# Iter 301: step_size = 2.2365e-01
# Iter 302: step_size = 2.2365e-01
# Iter 303: step_size = 2.2365e-01
# Iter 304: step_size = 2.2365e-01
# Iter 305: step_size = 2.2365e-01
# Iter 306: step_size = 2.2365e-01
# Iter 307: step_size = 2.2365e-01
# Iter 308: step_size = 2.2365e-01
# Iter 309: step_size = 2.2365e-01
# Iter 310: step_size = 2.2365e-01
# Iter 311: step_size = 2.2365e-01
# Iter 312: step_size = 2.2365e-01
# Iter 313: step_size = 2.2365e-01
# Iter 314: step_size = 2.2365e-01
# Iter 315: step_size = 2.2365e-01
# Iter 316: step_size = 2.2365e-01
# Iter 317: step_size = 2.2365e-01
# Iter 318: step_size = 2.2365e-01
# Iter 319: step_size = 2.2365e-01
# Iter 320: step_size = 2.2365e-01
# Iter 321: step_size = 2.2365e-01
# Iter 322: step_size = 2.2365e-01
# Iter 323: step_size = 2.2365e-01
# Iter 324: step_size = 2.2365e-01
# Iter 325: step_size = 2.2365e-01
# Iter 326: step_size = 2.2365e-01
# Iter 327: step_size = 2.2365e-01
# Iter 328: step_size = 2.2365e-01
# Iter 329: step_size = 2.2365e-01
# Iter 330: step_size = 2.2365e-01
# Iter 331: step_size = 2.2365e-01
# Iter 332: step_size = 2.2365e-01
# Iter 333: step_size = 2.2365e-01
# Iter 334: step_size = 2.2365e-01
# Iter 335: step_size = 2.2365e-01
# Iter 336: step_size = 2.2365e-01
# Iter 337: step_size = 2.2365e-01
# Iter 338: step_size = 2.2365e-01
# Iter 339: step_size = 2.2365e-01
# Iter 340: step_size = 2.2365e-01
# Iter 341: step_size = 2.2365e-01
# Iter 342: step_size = 2.2365e-01
# Iter 343: step_size = 2.2365e-01
# Iter 344: step_size = 2.2365e-01
# Iter 345: step_size = 2.2365e-01
# Iter 346: step_size = 2.2365e-01
# Iter 347: step_size = 2.2365e-01
# Iter 348: step_size = 2.2365e-01
# Iter 349: step_size = 2.2365e-01
# Iter 350: step_size = 2.2365e-01
# Iter 351: step_size = 2.2365e-01
# Iter 352: step_size = 2.2365e-01
# Iter 353: step_size = 2.2365e-01
# Iter 354: step_size = 2.2365e-01
# Iter 355: step_size = 2.2365e-01
# Iter 356: step_size = 2.2365e-01
# Iter 357: step_size = 2.2365e-01
# Iter 358: step_size = 2.2365e-01
# Iter 359: step_size = 2.2365e-01
# Iter 360: step_size = 2.2365e-01
# Iter 361: step_size = 2.2365e-01
# Iter 362: step_size = 2.2365e-01
# Iter 363: step_size = 2.2365e-01
# Iter 364: step_size = 2.2365e-01
# Iter 365: step_size = 2.2365e-01
# Iter 366: step_size = 2.2365e-01
# Iter 367: step_size = 2.2365e-01
# Iter 368: step_size = 2.2365e-01
# Iter 369: step_size = 2.2365e-01
# Iter 370: step_size = 2.2365e-01
# Iter 371: step_size = 2.2365e-01
# Iter 372: step_size = 2.2365e-01
# Iter 373: step_size = 2.2365e-01
# Iter 374: step_size = 2.2365e-01
# Iter 375: step_size = 2.2365e-01
# Iter 376: step_size = 2.2365e-01
# Iter 377: step_size = 2.2365e-01
# Iter 378: step_size = 2.2365e-01
# Iter 379: step_size = 2.2365e-01
# Iter 380: step_size = 2.2365e-01
# Iter 381: step_size = 2.2365e-01
# Iter 382: step_size = 2.2365e-01
# Iter 383: step_size = 2.2365e-01
# Iter 384: step_size = 2.2365e-01
# Iter 385: step_size = 2.2365e-01
# Iter 386: step_size = 2.2365e-01
# Iter 387: step_size = 2.2365e-01
# Iter 388: step_size = 2.2365e-01
# Iter 389: step_size = 2.2365e-01
# Iter 390: step_size = 2.2365e-01
# Iter 391: step_size = 2.2365e-01
# Iter 392: step_size = 2.2365e-01
# Iter 393: step_size = 2.2365e-01
# Iter 394: step_size = 2.2365e-01
# Iter 395: step_size = 2.2365e-01
# Iter 396: step_size = 2.2365e-01
# Iter 397: step_size = 2.2365e-01
# Iter 398: step_size = 2.2365e-01
# Iter 399: step_size = 2.2365e-01
# Iter 400: step_size = 2.2365e-01
# Iter 401: step_size = 2.2365e-01
# Iter 402: step_size = 2.2365e-01
# Iter 403: step_size = 2.2365e-01
# Iter 404: step_size = 2.2365e-01
# Iter 405: step_size = 2.2365e-01
# Iter 406: step_size = 2.2365e-01
# Iter 407: step_size = 2.2365e-01
# Iter 408: step_size = 2.2365e-01
# Iter 409: step_size = 2.2365e-01
# Iter 410: step_size = 2.2365e-01
# Iter 411: step_size = 2.2365e-01
# Iter 412: step_size = 2.2365e-01
# Iter 413: step_size = 2.2365e-01
# Iter 414: step_size = 2.2365e-01
# Iter 415: step_size = 2.2365e-01
# Iter 416: step_size = 2.2365e-01
# Iter 417: step_size = 2.2365e-01
# Iter 418: step_size = 2.2365e-01
# Iter 419: step_size = 2.2365e-01
# Iter 420: step_size = 2.2365e-01
# Iter 421: step_size = 2.2365e-01
# Iter 422: step_size = 2.2365e-01
# Iter 423: step_size = 2.2365e-01
# Iter 424: step_size = 2.2365e-01
# Iter 425: step_size = 2.2365e-01
# Iter 426: step_size = 2.2365e-01
# Iter 427: step_size = 2.2365e-01
# Iter 428: step_size = 2.2365e-01
# Iter 429: step_size = 2.2365e-01
# Iter 430: step_size = 2.2365e-01
# Iter 431: step_size = 2.2365e-01
# Iter 432: step_size = 2.2365e-01
# Iter 433: step_size = 2.2365e-01
# Iter 434: step_size = 2.2365e-01
# Iter 435: step_size = 2.2365e-01
# Iter 436: step_size = 2.2365e-01
# Iter 437: step_size = 2.2365e-01
# Iter 438: step_size = 2.2365e-01
# Iter 439: step_size = 2.2365e-01
# Iter 440: step_size = 2.2365e-01
# Iter 441: step_size = 2.2365e-01
# Iter 442: step_size = 2.2365e-01
# Iter 443: step_size = 2.2365e-01
# Iter 444: step_size = 2.2365e-01
# Iter 445: step_size = 2.2365e-01
# Iter 446: step_size = 2.2365e-01
# Iter 447: step_size = 2.2365e-01
# Iter 448: step_size = 2.2365e-01
# Iter 449: step_size = 2.2365e-01
# Iter 450: step_size = 2.2365e-01
# Iter 451: step_size = 2.2365e-01
# Iter 452: step_size = 2.2365e-01
# Iter 453: step_size = 2.2365e-01
# Iter 454: step_size = 2.2365e-01
# Iter 455: step_size = 2.2365e-01
# Iter 456: step_size = 2.2365e-01
# Iter 457: step_size = 2.2365e-01
# Iter 458: step_size = 2.2365e-01
# Iter 459: step_size = 2.2365e-01
# Iter 460: step_size = 2.2365e-01
# Iter 461: step_size = 2.2365e-01
# Iter 462: step_size = 2.2365e-01
# Iter 463: step_size = 2.2365e-01
# Iter 464: step_size = 2.2365e-01
# Iter 465: step_size = 2.2365e-01
# Iter 466: step_size = 2.2365e-01
# Iter 467: step_size = 2.2365e-01
# Iter 468: step_size = 2.2365e-01
# Iter 469: step_size = 2.2365e-01
# Iter 470: step_size = 2.2365e-01
# Iter 471: step_size = 2.2365e-01
# Iter 472: step_size = 2.2365e-01
# Iter 473: step_size = 2.2365e-01
# Iter 474: step_size = 2.2365e-01
# Iter 475: step_size = 2.2365e-01
# Iter 476: step_size = 2.2365e-01
# Iter 477: step_size = 2.2365e-01
# Iter 478: step_size = 2.2365e-01
# Iter 479: step_size = 2.2365e-01
# Iter 480: step_size = 2.2365e-01
# Iter 481: step_size = 2.2365e-01
# Iter 482: step_size = 2.2365e-01
# Iter 483: step_size = 2.2365e-01
# Iter 484: step_size = 2.2365e-01
# Iter 485: step_size = 2.2365e-01
# Iter 486: step_size = 2.2365e-01
# Iter 487: step_size = 2.2365e-01
# Iter 488: step_size = 2.2365e-01
# Iter 489: step_size = 2.2365e-01
# Iter 490: step_size = 2.2365e-01
# Iter 491: step_size = 2.2365e-01
# Iter 492: step_size = 2.2365e-01
# Iter 493: step_size = 2.2365e-01
# Iter 494: step_size = 2.2365e-01
# Iter 495: step_size = 2.2365e-01
# Iter 496: step_size = 2.2365e-01
# Iter 497: step_size = 2.2365e-01
# Iter 498: step_size = 2.2365e-01
# Iter 499: step_size = 2.2365e-01
# Iter 500: step_size = 2.2365e-01
# Iter 501: step_size = 2.2365e-01
# Iter 502: step_size = 2.2365e-01
# Iter 503: step_size = 2.2365e-01
# Iter 504: step_size = 2.2365e-01
# Iter 505: step_size = 2.2365e-01
# Iter 506: step_size = 2.2365e-01
# Iter 507: step_size = 2.2365e-01
# Iter 508: step_size = 2.2365e-01
# Iter 509: step_size = 2.2365e-01
# Iter 510: step_size = 2.2365e-01
# Iter 511: step_size = 2.2365e-01
# Iter 512: step_size = 2.2365e-01
# Iter 513: step_size = 2.2365e-01
# Iter 514: step_size = 2.2365e-01
# Iter 515: step_size = 2.2365e-01
# Iter 516: step_size = 2.2365e-01
# Iter 517: step_size = 2.2365e-01
# Iter 518: step_size = 2.2365e-01
# Iter 519: step_size = 2.2365e-01
# Iter 520: step_size = 2.2365e-01
# Iter 521: step_size = 2.2365e-01
# Iter 522: step_size = 2.2365e-01
# Iter 523: step_size = 2.2365e-01
# Iter 524: step_size = 2.2365e-01
# Iter 525: step_size = 2.2365e-01
# Iter 526: step_size = 2.2365e-01
# Iter 527: step_size = 2.2365e-01
# Iter 528: step_size = 2.2365e-01
# Iter 529: step_size = 2.2365e-01
# Iter 530: step_size = 2.2365e-01
# Iter 531: step_size = 2.2365e-01
# Iter 532: step_size = 2.2365e-01
# Converged in 532 iterations.
# Obj: 2860.0665306673345
# Running time= 0.09176826477050781

# %%
# Sample data
n, d = X.shape
lambda_reg = 0.1
# Parameters
L = np.linalg.norm(X, ord=2) ** 2 / n  # Lipschitz constant
def lasso_objective(beta,X,y):
    residual = X @ beta - y
    return (1 / (2 * n)) * np.sum(np.dot(residual,residual )) + lambda_reg * np.linalg.norm(beta, 1)

# %%
#Fixed step size
from proxop import L1Norm
def ista(X, y, L, lambda_reg=0.1, max_iter=1000, epsilon=1e-6):
  """
    Iterative Soft-Thresholding Algorithm (ISTA) to solve:
        min_beta (1/2n)||Xβ - y||² + λ||β||₁

    Parameters:
    - X: Feature matrix (standardized)
    - y: Target vector
    - lambda_: Regularization parameter controlling sparsity
    - step_size: Learning rate (must be <= 1 / Lipschitz constant of ∇f)
    - max_iter: Maximum number of iterations
    - epsilon: Convergence tolerance for stopping criterion

    Returns:
    - beta: Estimated coefficient vector
    """
  # Initialize parameters
  step_size = 1 / L
  beta = np.ones(d)

  # Define the proximal operator for L1 regularization
  prox_g = L1Norm(lambda_reg)

  # Proximal Gradient Descent loop
  for i in range(max_iter):
      gradient = (1 / n) * X.T @ (X @ beta - y)  # Gradient of MSE
      norm = np.linalg.norm(gradient)
      beta_prev = beta.copy()
      beta = prox_g.prox(beta - step_size * gradient, step_size) # Proximal update
      print(f"Iter {i}: Obj = {lasso_objective(beta,X,y):.6f}")

      # Check for convergence
      if abs(lasso_objective(beta,X,y) - lasso_objective(beta_prev,X,y))/max(1,abs(lasso_objective(beta_prev,X,y))) < epsilon:
          print(f"Converged in {i} iterations")
          break

  # Final beta
  return beta


start_time = time.time()
beta_opt= ista(X,y,L)
end_time= time.time()
print(f"Obj = {lasso_objective(beta_opt,X,y):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8270.672880
# Iter 1: Obj = 5329.045639
# Iter 2: Obj = 3668.846642
# Iter 3: Obj = 2728.546706
# Iter 4: Obj = 2193.469277
# Iter 5: Obj = 1888.039455
# Iter 6: Obj = 1713.143942
# Iter 7: Obj = 1612.539628
# Iter 8: Obj = 1554.308485
# Iter 9: Obj = 1520.346478
# Iter 10: Obj = 1500.356690
# Iter 11: Obj = 1488.458228
# Iter 12: Obj = 1481.279747
# Iter 13: Obj = 1476.879568
# Iter 14: Obj = 1474.132868
# Iter 15: Obj = 1472.383253
# Iter 16: Obj = 1471.244208
# Iter 17: Obj = 1470.485622
# Iter 18: Obj = 1469.968685
# Iter 19: Obj = 1469.608381
# Iter 20: Obj = 1469.351728
# Iter 21: Obj = 1469.165084
# Iter 22: Obj = 1469.026657
# Iter 23: Obj = 1468.922042
# Iter 24: Obj = 1468.841529
# Iter 25: Obj = 1468.778450
# Iter 26: Obj = 1468.728147
# Iter 27: Obj = 1468.687321
# Iter 28: Obj = 1468.653601
# Iter 29: Obj = 1468.625268
# Iter 30: Obj = 1468.601061
# Iter 31: Obj = 1468.580053
# Iter 32: Obj = 1468.561552
# Iter 33: Obj = 1468.545042
# Iter 34: Obj = 1468.530134
# Iter 35: Obj = 1468.516536
# Iter 36: Obj = 1468.504023
# Iter 37: Obj = 1468.492425
# Iter 38: Obj = 1468.481608
# Iter 39: Obj = 1468.471470
# Iter 40: Obj = 1468.461928
# Iter 41: Obj = 1468.452917
# Iter 42: Obj = 1468.444382
# Iter 43: Obj = 1468.436279
# Iter 44: Obj = 1468.428571
# Iter 45: Obj = 1468.421225
# Iter 46: Obj = 1468.414212
# Iter 47: Obj = 1468.407507
# Iter 48: Obj = 1468.401086
# Iter 49: Obj = 1468.394928
# Iter 50: Obj = 1468.389014
# Iter 51: Obj = 1468.383325
# Iter 52: Obj = 1468.377842
# Iter 53: Obj = 1468.372549
# Iter 54: Obj = 1468.367431
# Iter 55: Obj = 1468.362471
# Iter 56: Obj = 1468.357655
# Iter 57: Obj = 1468.352969
# Iter 58: Obj = 1468.348399
# Iter 59: Obj = 1468.343932
# Iter 60: Obj = 1468.339556
# Iter 61: Obj = 1468.335259
# Iter 62: Obj = 1468.331030
# Iter 63: Obj = 1468.326857
# Iter 64: Obj = 1468.322729
# Iter 65: Obj = 1468.318638
# Iter 66: Obj = 1468.314573
# Iter 67: Obj = 1468.310526
# Iter 68: Obj = 1468.306487
# Iter 69: Obj = 1468.302449
# Iter 70: Obj = 1468.298404
# Iter 71: Obj = 1468.294344
# Iter 72: Obj = 1468.290263
# Iter 73: Obj = 1468.286154
# Iter 74: Obj = 1468.282011
# Iter 75: Obj = 1468.277828
# Iter 76: Obj = 1468.273600
# Iter 77: Obj = 1468.269321
# Iter 78: Obj = 1468.264987
# Iter 79: Obj = 1468.260594
# Iter 80: Obj = 1468.256136
# Iter 81: Obj = 1468.251612
# Iter 82: Obj = 1468.247016
# Iter 83: Obj = 1468.242346
# Iter 84: Obj = 1468.237598
# Iter 85: Obj = 1468.226814
# Iter 86: Obj = 1468.202694
# Iter 87: Obj = 1468.183417
# Iter 88: Obj = 1468.164094
# Iter 89: Obj = 1468.118455
# Iter 90: Obj = 1468.073120
# Iter 91: Obj = 1468.032903
# Iter 92: Obj = 1467.998352
# Iter 93: Obj = 1467.968894
# Iter 94: Obj = 1467.943768
# Iter 95: Obj = 1467.922273
# Iter 96: Obj = 1467.903813
# Iter 97: Obj = 1467.887899
# Iter 98: Obj = 1467.874127
# Iter 99: Obj = 1467.862167
# Iter 100: Obj = 1467.851744
# Iter 101: Obj = 1467.842630
# Iter 102: Obj = 1467.834637
# Iter 103: Obj = 1467.827606
# Iter 104: Obj = 1467.821403
# Iter 105: Obj = 1467.815916
# Iter 106: Obj = 1467.811051
# Iter 107: Obj = 1467.806726
# Iter 108: Obj = 1467.802873
# Iter 109: Obj = 1467.799432
# Iter 110: Obj = 1467.796355
# Iter 111: Obj = 1467.793596
# Iter 112: Obj = 1467.791118
# Iter 113: Obj = 1467.788889
# Iter 114: Obj = 1467.786880
# Iter 115: Obj = 1467.785068
# Iter 116: Obj = 1467.783430
# Iter 117: Obj = 1467.781947
# Iter 118: Obj = 1467.780603
# Converged in 118 iterations
# Obj = 1467.780603
# Running time= 0.026637554168701172

# %%
#Adaptive step size
from proxop import L1Norm
def ista(X, y, L, lambda_reg=0.1, max_iter=1000, epsilon=1e-6):
  """
    Iterative Soft-Thresholding Algorithm (ISTA) to solve:
        min_beta (1/2n)||Xβ - y||² + λ||β||₁

    Parameters:
    - X: Feature matrix (standardized)
    - y: Target vector
    - lambda_: Regularization parameter controlling sparsity
    - step_size: Learning rate (must be <= 1 / Lipschitz constant of ∇f)
    - max_iter: Maximum number of iterations
    - epsilon: Convergence tolerance for stopping criterion

    Returns:
    - beta: Estimated coefficient vector
    """
  # Initialize parameters
  t_init=1
  beta = np.ones(d)

  # Define the proximal operator for L1 regularization
  prox_g = L1Norm(lambda_reg)

  # Proximal Gradient Descent loop
  for i in range(max_iter):
      gradient = (1 / n) * X.T @ (X @ beta - y)  # Gradient of MSE
      norm = np.linalg.norm(gradient)
      beta_prev = beta.copy()
      eta = backtracking_line_search(X, y, beta, gradient, L,t_init)
      t_init=eta
      beta = prox_g.prox(beta - eta * gradient, eta)
      print(f"Iter {i}: Obj = {lasso_objective(beta,X,y):.6f}")

      # Check for convergence
      if abs(lasso_objective(beta,X,y) - lasso_objective(beta_prev,X,y))/max(1,abs(lasso_objective(beta_prev,X,y))) < epsilon:
          print(f"Converged in {i} iterations")
          break

  # Final beta
  return beta


start_time = time.time()
beta_opt= ista(X,y,L)
end_time= time.time()
print(f"Obj = {lasso_objective(beta_opt,X,y):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8737.801791
# Iter 1: Obj = 5860.787710
# Iter 2: Obj = 4134.844259
# Iter 3: Obj = 3093.047368
# Iter 4: Obj = 2461.641037
# Iter 5: Obj = 2078.066948
# Iter 6: Obj = 1844.483259
# Iter 7: Obj = 1701.887785
# Iter 8: Obj = 1614.492117
# Iter 9: Obj = 1560.660695
# Iter 10: Obj = 1527.311027
# Iter 11: Obj = 1506.507208
# Iter 12: Obj = 1493.421883
# Iter 13: Obj = 1485.110343
# Iter 14: Obj = 1479.770305
# Iter 15: Obj = 1476.294202
# Iter 16: Obj = 1473.998000
# Iter 17: Obj = 1472.456680
# Iter 18: Obj = 1471.404230
# Iter 19: Obj = 1470.672710
# Iter 20: Obj = 1470.155018
# Iter 21: Obj = 1469.782050
# Iter 22: Obj = 1469.508636
# Iter 23: Obj = 1469.304825
# Iter 24: Obj = 1469.150453
# Iter 25: Obj = 1469.031728
# Iter 26: Obj = 1468.939067
# Iter 27: Obj = 1468.865711
# Iter 28: Obj = 1468.806818
# Iter 29: Obj = 1468.758877
# Iter 30: Obj = 1468.719309
# Iter 31: Obj = 1468.686199
# Iter 32: Obj = 1468.658115
# Iter 33: Obj = 1468.633973
# Iter 34: Obj = 1468.612950
# Iter 35: Obj = 1468.594417
# Iter 36: Obj = 1468.577890
# Iter 37: Obj = 1468.562996
# Iter 38: Obj = 1468.549445
# Iter 39: Obj = 1468.537009
# Iter 40: Obj = 1468.525512
# Iter 41: Obj = 1468.514815
# Iter 42: Obj = 1468.504805
# Iter 43: Obj = 1468.495395
# Iter 44: Obj = 1468.486512
# Iter 45: Obj = 1468.478100
# Iter 46: Obj = 1468.470110
# Iter 47: Obj = 1468.462503
# Iter 48: Obj = 1468.455244
# Iter 49: Obj = 1468.448304
# Iter 50: Obj = 1468.441660
# Iter 51: Obj = 1468.435288
# Iter 52: Obj = 1468.429168
# Iter 53: Obj = 1468.423283
# Iter 54: Obj = 1468.417616
# Iter 55: Obj = 1468.412153
# Iter 56: Obj = 1468.406877
# Iter 57: Obj = 1468.401777
# Iter 58: Obj = 1468.396839
# Iter 59: Obj = 1468.392050
# Iter 60: Obj = 1468.387400
# Iter 61: Obj = 1468.382878
# Iter 62: Obj = 1468.378471
# Iter 63: Obj = 1468.374171
# Iter 64: Obj = 1468.369967
# Iter 65: Obj = 1468.365849
# Iter 66: Obj = 1468.361809
# Iter 67: Obj = 1468.357837
# Iter 68: Obj = 1468.353926
# Iter 69: Obj = 1468.350066
# Iter 70: Obj = 1468.346251
# Iter 71: Obj = 1468.342472
# Iter 72: Obj = 1468.338722
# Iter 73: Obj = 1468.334994
# Iter 74: Obj = 1468.331283
# Iter 75: Obj = 1468.327580
# Iter 76: Obj = 1468.323881
# Iter 77: Obj = 1468.320180
# Iter 78: Obj = 1468.316471
# Iter 79: Obj = 1468.312748
# Iter 80: Obj = 1468.309008
# Iter 81: Obj = 1468.305245
# Iter 82: Obj = 1468.301455
# Iter 83: Obj = 1468.297633
# Iter 84: Obj = 1468.293776
# Iter 85: Obj = 1468.289880
# Iter 86: Obj = 1468.285941
# Iter 87: Obj = 1468.281956
# Iter 88: Obj = 1468.277922
# Iter 89: Obj = 1468.273836
# Iter 90: Obj = 1468.269695
# Iter 91: Obj = 1468.265496
# Iter 92: Obj = 1468.261238
# Iter 93: Obj = 1468.256918
# Iter 94: Obj = 1468.251359
# Iter 95: Obj = 1468.228180
# Iter 96: Obj = 1468.210045
# Iter 97: Obj = 1468.192953
# Iter 98: Obj = 1468.175905
# Iter 99: Obj = 1468.149119
# Iter 100: Obj = 1468.108134
# Iter 101: Obj = 1468.068746
# Iter 102: Obj = 1468.033374
# Iter 103: Obj = 1468.002370
# Iter 104: Obj = 1467.975406
# Iter 105: Obj = 1467.951983
# Iter 106: Obj = 1467.931607
# Iter 107: Obj = 1467.913835
# Iter 108: Obj = 1467.898291
# Iter 109: Obj = 1467.884656
# Iter 110: Obj = 1467.872660
# Iter 111: Obj = 1467.862077
# Iter 112: Obj = 1467.852715
# Iter 113: Obj = 1467.844412
# Iter 114: Obj = 1467.837031
# Iter 115: Obj = 1467.830452
# Iter 116: Obj = 1467.824576
# Iter 117: Obj = 1467.819316
# Iter 118: Obj = 1467.814598
# Iter 119: Obj = 1467.810358
# Iter 120: Obj = 1467.806539
# Iter 121: Obj = 1467.803095
# Iter 122: Obj = 1467.799982
# Iter 123: Obj = 1467.797165
# Iter 124: Obj = 1467.794611
# Iter 125: Obj = 1467.792293
# Iter 126: Obj = 1467.790185
# Iter 127: Obj = 1467.788266
# Iter 128: Obj = 1467.786516
# Iter 129: Obj = 1467.784920
# Iter 130: Obj = 1467.783461
# Converged in 130 iterations
# Obj = 1467.783461
# Running time= 0.04696011543273926

# %%
#Fixed step size
from proxop import L1Norm



# Parameters
step_size = 1 / L
max_iter = 1000
epsilon = 1e-6
def fista(X, y, L, lambda_reg=0.1, max_iter=1000, epsilon=1e-6):
    """
    Fast Iterative Soft-Thresholding Algorithm (FISTA) for LASSO:
        Solves: min_beta (1/2n)||Xβ - y||² + λ||β||₁

    Parameters:
    - X (ndarray): Feature matrix (n_samples, n_features), should be standardized
    - y (ndarray): Target vector (n_samples,)
    - L (float): Lipschitz constant of the gradient ∇f = (1/n) * Xᵀ(Xβ - y)
    - lambda_reg (float): L1 regularization parameter controlling sparsity
    - max_iter (int): Maximum number of iterations
    - epsilon (float): Convergence tolerance on relative objective change

    Returns:
    - beta (ndarray): Optimized coefficient vector
      """
    # Initialize parameters
    d = X.shape[1]
    n = X.shape[0]
    beta = np.ones(d)          # Current estimate
    theta = beta.copy()         # Extrapolated point
    t = 1                       # FISTA momentum parameter


    # Define the proximal operator for L1 regularization
    prox_g = L1Norm(lambda_reg)

    # FISTA loop
    for i in range(max_iter):
        gradient = (1 / n) * X.T @ (X @ theta - y)  # Gradient at theta
        beta_next = prox_g.prox(theta - step_size * gradient, step_size)

        # Momentum update
        t_next = (1 + np.sqrt(1 + 4 * t**2)) / 2
        theta = beta_next + ((t - 1) / t_next) * (beta_next - beta)
        print(f"Iter {i}: Obj = {lasso_objective(beta_next,X,y):.6f}")

        # Check for convergence
        if abs(lasso_objective(beta_next,X,y) - lasso_objective(beta,X,y))/max(1,abs(lasso_objective(beta,X,y))) < epsilon:
            print(f"Converged in {i} iterations")
            break

        # Update variables
        beta = beta_next
        t = t_next

    # Final beta
    return beta
start_time = time.time()
beta_opt= fista(X,y,L)
end_time = time.time()
print(f"Obj = {lasso_objective(beta_opt,X,y):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8270.672880
# Iter 1: Obj = 5329.045639
# Iter 2: Obj = 3285.495028
# Iter 3: Obj = 2140.963439
# Iter 4: Obj = 1639.925580
# Iter 5: Obj = 1487.547522
# Iter 6: Obj = 1469.805172
# Iter 7: Obj = 1478.144743
# Iter 8: Obj = 1479.261034
# Iter 9: Obj = 1474.009908
# Iter 10: Obj = 1469.425176
# Iter 11: Obj = 1468.302112
# Iter 12: Obj = 1469.409008
# Iter 13: Obj = 1470.641984
# Iter 14: Obj = 1470.949273
# Iter 15: Obj = 1470.431174
# Iter 16: Obj = 1469.630785
# Iter 17: Obj = 1468.959247
# Iter 18: Obj = 1468.545574
# Iter 19: Obj = 1468.348394
# Iter 20: Obj = 1468.094764
# Iter 21: Obj = 1468.025379
# Iter 22: Obj = 1467.938603
# Iter 23: Obj = 1467.710130
# Iter 24: Obj = 1467.484457
# Iter 25: Obj = 1467.388895
# Iter 26: Obj = 1467.389260
# Converged in 26 iterations
# Obj = 1467.388895
# Running time= 0.00891423225402832

# %%
#Adaptive step size
from proxop import L1Norm



# Parameters
L = np.linalg.norm(X, ord=2) ** 2 / n  # Lipschitz constant

max_iter = 1000
epsilon = 1e-6
def fista(X, y, L, lambda_reg=0.1, max_iter=1000, epsilon=1e-6):
  # Initialize parameters
  t_init= 1
  beta = np.ones(d)          # Current estimate
  theta = beta.copy()         # Extrapolated point
  t = 1                       # FISTA momentum parameter

  # Define the proximal operator for L1 regularization
  prox_g = L1Norm(lambda_reg)

  # FISTA loop
  for i in range(max_iter):
      gradient = (1 / n) * X.T @ (X @ theta - y)  # Gradient at theta
      eta = backtracking_line_search(X, y, beta, gradient, L,t_init)
      t_init=eta
      beta_next = prox_g.prox(theta - eta * gradient, eta)

      # Momentum update
      t_next = (1 + np.sqrt(1 + 4 * t**2)) / 2
      theta = beta_next + ((t - 1) / t_next) * (beta_next - beta)
      print(f"Iter {i}: Obj = {lasso_objective(beta_next,X,y):.6f}")

      # Check for convergence
      if abs(lasso_objective(beta_next,X,y) - lasso_objective(beta,X,y))/max(1,abs(lasso_objective(beta,X,y))) < epsilon:
          print(f"Converged in {i} iterations")
          break

      # Update variables
      beta = beta_next
      t = t_next

  # Final beta
  return beta
start_time = time.time()
beta_opt= fista(X,y,L)
end_time = time.time()
print(f"Obj = {lasso_objective(beta_opt,X,y):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8737.801791
# Iter 1: Obj = 5860.787710
# Iter 2: Obj = 3725.523632
# Iter 3: Obj = 2416.770641
# Iter 4: Obj = 1766.105723
# Iter 5: Obj = 1522.454196
# Iter 6: Obj = 1469.791995
# Iter 7: Obj = 1475.282322
# Iter 8: Obj = 1482.163881
# Iter 9: Obj = 1479.432013
# Iter 10: Obj = 1472.991767
# Iter 11: Obj = 1468.827124
# Iter 12: Obj = 1468.289098
# Iter 13: Obj = 1469.671766
# Iter 14: Obj = 1470.952202
# Iter 15: Obj = 1471.215358
# Iter 16: Obj = 1470.613743
# Iter 17: Obj = 1469.708063
# Iter 18: Obj = 1468.934030
# Iter 19: Obj = 1468.443028
# Iter 20: Obj = 1468.196892
# Iter 21: Obj = 1467.963931
# Iter 22: Obj = 1467.852637
# Iter 23: Obj = 1467.665893
# Iter 24: Obj = 1467.492094
# Iter 25: Obj = 1467.371741
# Iter 26: Obj = 1467.349343
# Iter 27: Obj = 1467.408359
# Iter 28: Obj = 1467.503156
# Iter 29: Obj = 1467.591300
# Iter 30: Obj = 1467.659696
# Iter 31: Obj = 1467.707828
# Iter 32: Obj = 1467.737767
# Iter 33: Obj = 1467.751998
# Iter 34: Obj = 1467.753894
# Iter 35: Obj = 1467.747831
# Iter 36: Obj = 1467.738455
# Iter 37: Obj = 1467.729753
# Iter 38: Obj = 1467.724520
# Iter 39: Obj = 1467.724368
# Converged in 39 iterations
# Obj = 1467.724520
# Running time= 0.015131235122680664

# %%
def ridge_objective(beta, X, y, lambda_reg):
    """
    Computes the Ridge regression objective function value.

    Parameters:
    - beta: Coefficient vector (numpy array of shape (d,))
    - X: Feature matrix (numpy array of shape (n_samples, n_features))
    - y: Target vector (numpy array of shape (n_samples,))
    - lambda_reg: Regularization parameter (float)

    Returns:
    - Objective function value (float)
    """
    n = X.shape[0]
    residual = X @ beta - y
    mse_term = (1 / (2 * n)) * np.dot(residual, residual)
    reg_term = (lambda_reg / 2) * np.dot(beta, beta)
    return mse_term + reg_term

# %%
#Fixed step size
from proxop.scalar import Square

n, d = X.shape

# Parameters
lambda_reg = 0.1  # Regularization parameter (λ)
step_size = 1 / L
max_iter = 1000
epsilon = 1e-6


# Initialize parameters
beta = np.ones(d)

# Initialize the Square proximal operator
square_prox = Square()

start_time = time.time()
# Proximal Gradient Descent loop
for i in range(max_iter):
    gradient = (1 / n) * X.T @ (X @ beta - y)  # Gradient of MSE
    beta_prev = beta.copy()
    beta_temp = beta - step_size * gradient
    # Apply proximal operator for L2 regularization (ridge penalty)
    beta = square_prox.prox(beta_temp, gamma=step_size * lambda_reg)
    objective_value = ridge_objective(beta, X, y, lambda_reg)
    print(f"Iter {i}: Obj = {objective_value:.6f}")

    # Check for convergence after minimum iterations
    if abs(ridge_objective(beta,X,y,lambda_reg) - ridge_objective(beta_prev,X,y,lambda_reg))/max(1,abs(ridge_objective(beta_prev,X,y,lambda_reg))) < epsilon:
        print(f"Converged in {i} iterations")
        break

end_time = time.time()

print(f"Obj = {ridge_objective(beta,X,y,lambda_reg):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8440.417923
# Iter 1: Obj = 5724.829627
# Iter 2: Obj = 4267.495296
# Iter 3: Obj = 3484.399518
# Iter 4: Obj = 3063.143841
# Iter 5: Obj = 2836.306536
# Iter 6: Obj = 2714.034647
# Iter 7: Obj = 2648.051802
# Iter 8: Obj = 2612.396362
# Iter 9: Obj = 2593.095745
# Iter 10: Obj = 2582.624159
# Iter 11: Obj = 2576.924924
# Iter 12: Obj = 2573.809412
# Iter 13: Obj = 2572.095605
# Iter 14: Obj = 2571.144310
# Iter 15: Obj = 2570.609321
# Iter 16: Obj = 2570.302735
# Iter 17: Obj = 2570.122297
# Iter 18: Obj = 2570.012168
# Iter 19: Obj = 2569.941717
# Iter 20: Obj = 2569.894043
# Iter 21: Obj = 2569.859747
# Iter 22: Obj = 2569.833550
# Iter 23: Obj = 2569.812447
# Iter 24: Obj = 2569.794700
# Iter 25: Obj = 2569.779281
# Iter 26: Obj = 2569.765565
# Iter 27: Obj = 2569.753161
# Iter 28: Obj = 2569.741813
# Iter 29: Obj = 2569.731350
# Iter 30: Obj = 2569.721648
# Iter 31: Obj = 2569.712616
# Iter 32: Obj = 2569.704184
# Iter 33: Obj = 2569.696295
# Iter 34: Obj = 2569.688904
# Iter 35: Obj = 2569.681970
# Iter 36: Obj = 2569.675459
# Iter 37: Obj = 2569.669341
# Iter 38: Obj = 2569.663588
# Iter 39: Obj = 2569.658177
# Iter 40: Obj = 2569.653084
# Iter 41: Obj = 2569.648289
# Iter 42: Obj = 2569.643773
# Iter 43: Obj = 2569.639520
# Iter 44: Obj = 2569.635511
# Iter 45: Obj = 2569.631734
# Iter 46: Obj = 2569.628173
# Iter 47: Obj = 2569.624816
# Iter 48: Obj = 2569.621650
# Iter 49: Obj = 2569.618664
# Iter 50: Obj = 2569.615847
# Iter 51: Obj = 2569.613189
# Iter 52: Obj = 2569.610681
# Converged in 52 iterations
# Obj = 2569.610681
# Running time= 0.008379697799682617

# %%
#Adaptive step size
from proxop.scalar import Square

n, d = X.shape

# Parameters
lambda_reg = 0.1
t_init = 1
max_iter = 1000
epsilon = 1e-6


# Initialize parameters
beta = np.ones(d)

# Initialize the Square proximal operator
square_prox = Square()
start_time = time.time()
# Proximal Gradient Descent loop
for i in range(max_iter):
    gradient = (1 / n) * X.T @ (X @ beta - y)  # Gradient of MSE
    # Use backtracking line search to find an appropriate step size
    eta = backtracking_line_search(X, y, beta, gradient, L,t_init)
    t_init=eta
    beta_prev = beta.copy()
    beta_temp = beta - eta * gradient
    beta = square_prox.prox(beta_temp, gamma=eta * lambda_reg)
    # Apply proximal operator for L2 regularization (ridge)
    objective_value = ridge_objective(beta, X, y, lambda_reg)
    print(f"Iter {i}: Obj = {objective_value:.6f}")

    # Check for convergence after minimum iterations
    if abs(ridge_objective(beta,X,y,lambda_reg) - ridge_objective(beta_prev,X,y,lambda_reg))/max(1,abs(ridge_objective(beta_prev,X,y,lambda_reg))) < epsilon:
        print(f"Converged in {i} iterations")
        break

end_time = time.time()

print(f"Obj = {ridge_objective(beta,X,y,lambda_reg):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8873.456029
# Iter 1: Obj = 6198.712663
# Iter 2: Obj = 4663.028166
# Iter 3: Obj = 3778.331432
# Iter 4: Obj = 3268.196945
# Iter 5: Obj = 2973.809240
# Iter 6: Obj = 2803.793747
# Iter 7: Obj = 2705.527289
# Iter 8: Obj = 2648.679928
# Iter 9: Obj = 2615.758856
# Iter 10: Obj = 2596.668919
# Iter 11: Obj = 2585.580742
# Iter 12: Obj = 2579.126164
# Iter 13: Obj = 2575.357809
# Iter 14: Obj = 2573.148924
# Iter 15: Obj = 2571.846988
# Iter 16: Obj = 2571.073714
# Iter 17: Obj = 2570.609510
# Iter 18: Obj = 2570.326693
# Iter 19: Obj = 2570.150871
# Iter 20: Obj = 2570.038587
# Iter 21: Obj = 2569.964372
# Iter 22: Obj = 2569.913237
# Iter 23: Obj = 2569.876314
# Iter 24: Obj = 2569.848321
# Iter 25: Obj = 2569.826085
# Iter 26: Obj = 2569.807678
# Iter 27: Obj = 2569.791916
# Iter 28: Obj = 2569.778056
# Iter 29: Obj = 2569.765623
# Iter 30: Obj = 2569.754307
# Iter 31: Obj = 2569.743900
# Iter 32: Obj = 2569.734255
# Iter 33: Obj = 2569.725267
# Iter 34: Obj = 2569.716860
# Iter 35: Obj = 2569.708971
# Iter 36: Obj = 2569.701554
# Iter 37: Obj = 2569.694568
# Iter 38: Obj = 2569.687979
# Iter 39: Obj = 2569.681760
# Iter 40: Obj = 2569.675884
# Iter 41: Obj = 2569.670330
# Iter 42: Obj = 2569.665076
# Iter 43: Obj = 2569.660105
# Iter 44: Obj = 2569.655399
# Iter 45: Obj = 2569.650943
# Iter 46: Obj = 2569.646722
# Iter 47: Obj = 2569.642724
# Iter 48: Obj = 2569.638934
# Iter 49: Obj = 2569.635343
# Iter 50: Obj = 2569.631938
# Iter 51: Obj = 2569.628709
# Iter 52: Obj = 2569.625648
# Iter 53: Obj = 2569.622744
# Iter 54: Obj = 2569.619989
# Iter 55: Obj = 2569.617376
# Iter 56: Obj = 2569.614896
# Converged in 56 iterations
# Obj = 2569.614896
# Running time= 0.020322084426879883

# %%
#Fixed step size
from proxop import L1Norm, Square

def elastic_net_objective(beta, X, y, lambda_reg, alpha):
  """
    Computes the Elastic Net objective function:
        (1/2n) * ||Xβ - y||^2 + λ * [α * ||β||_1 + (1 - α)/2 * ||β||_2^2]

    Parameters:
        beta : ndarray
            Coefficient vector.
        X : ndarray
            Feature matrix.
        y : ndarray
            Target vector.
        lambda_reg : float
            Regularization strength.
        alpha : float
            Elastic net mixing parameter (0 = Ridge, 1 = Lasso).

    Returns:
        float: The value of the Elastic Net objective function.
  """
  n = X.shape[0]
  residual = X @ beta - y
  mse_term = (1 / (2 * n)) * np.dot(residual, residual)
  l1_term = lambda_reg * alpha * np.sum(np.abs(beta))
  l2_term = (lambda_reg * (1 - alpha) / 2) * np.dot(beta, beta)
  return mse_term + l1_term + l2_term

# Sample data
n, d = X.shape

# Parameters
lambda_reg = 0.1  # Regularization strength
alpha = 0.027    # Mixing parameter between L1 and L2
step_size = 1 / L
max_iter = 1000
epsilon = 1e-6

# Initialize parameters
beta = np.ones(d)

# Initialize proximal operators
prox_l1 = L1Norm(lambda_reg * alpha)
prox_l2 = Square()
start_time = time.time()
# Proximal Gradient Descent loop
for i in range(max_iter):
    # Compute the gradient of the MSE term
    gradient = (1 / n) * X.T @ (X @ beta - y)
    beta_prev = beta.copy()

    # Gradient step
    beta_temp = beta - step_size * gradient

    # Apply the proximal operator for the squared L2 norm
    beta_temp = prox_l2.prox(beta_temp, gamma=step_size * lambda_reg * (1 - alpha))

    # Apply the proximal operator for the L1 norm
    beta = prox_l1.prox(beta_temp, gamma=step_size)

    # Compute the objective function value
    obj_value = elastic_net_objective(beta, X, y, lambda_reg, alpha)
    print(f"Iter {i}: Obj = {obj_value:.6f}")

    # Check for convergence
    if abs(elastic_net_objective(beta,X,y,lambda_reg, alpha) - elastic_net_objective(beta_prev,X,y,lambda_reg, alpha))/max(1,abs(elastic_net_objective(beta_prev,X,y,lambda_reg, alpha))) < epsilon:
        print(f"Converged in {i} iterations")
        break

end_time = time.time()
print(f"Obj={elastic_net_objective(beta,X,y,lambda_reg, alpha):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8463.444028
# Iter 1: Obj = 5752.718214
# Iter 2: Obj = 4292.656718
# Iter 3: Obj = 3503.049589
# Iter 4: Obj = 3073.726523
# Iter 5: Obj = 2839.341682
# Iter 6: Obj = 2710.775573
# Iter 7: Obj = 2639.782685
# Iter 8: Obj = 2600.297109
# Iter 9: Obj = 2578.096871
# Iter 10: Obj = 2565.458466
# Iter 11: Obj = 2558.156050
# Iter 12: Obj = 2553.863768
# Iter 13: Obj = 2551.292301
# Iter 14: Obj = 2549.720419
# Iter 15: Obj = 2548.740076
# Iter 16: Obj = 2548.117181
# Iter 17: Obj = 2547.715191
# Iter 18: Obj = 2547.452913
# Iter 19: Obj = 2547.281022
# Iter 20: Obj = 2547.168855
# Iter 21: Obj = 2547.096896
# Iter 22: Obj = 2547.052433
# Iter 23: Obj = 2547.027008
# Iter 24: Obj = 2547.014880
# Iter 25: Obj = 2547.012087
# Iter 26: Obj = 2547.015857
# Iter 27: Obj = 2547.024229
# Iter 28: Obj = 2547.035798
# Iter 29: Obj = 2547.049558
# Iter 30: Obj = 2547.064777
# Iter 31: Obj = 2547.080926
# Iter 32: Obj = 2547.097620
# Iter 33: Obj = 2547.114577
# Iter 34: Obj = 2547.131592
# Iter 35: Obj = 2547.148518
# Iter 36: Obj = 2547.165244
# Iter 37: Obj = 2547.181695
# Iter 38: Obj = 2547.197813
# Iter 39: Obj = 2547.213561
# Iter 40: Obj = 2547.228911
# Iter 41: Obj = 2547.243845
# Iter 42: Obj = 2547.258354
# Iter 43: Obj = 2547.272431
# Iter 44: Obj = 2547.286075
# Iter 45: Obj = 2547.299286
# Iter 46: Obj = 2547.312069
# Iter 47: Obj = 2547.324428
# Iter 48: Obj = 2547.336369
# Iter 49: Obj = 2547.347901
# Iter 50: Obj = 2547.359030
# Iter 51: Obj = 2547.369765
# Iter 52: Obj = 2547.380116
# Iter 53: Obj = 2547.390092
# Iter 54: Obj = 2547.399702
# Iter 55: Obj = 2547.408955
# Iter 56: Obj = 2547.417863
# Iter 57: Obj = 2547.426434
# Iter 58: Obj = 2547.434678
# Iter 59: Obj = 2547.442605
# Iter 60: Obj = 2547.450224
# Iter 61: Obj = 2547.457546
# Iter 62: Obj = 2547.464579
# Iter 63: Obj = 2547.471334
# Iter 64: Obj = 2547.477818
# Iter 65: Obj = 2547.484042
# Iter 66: Obj = 2547.490014
# Iter 67: Obj = 2547.495742
# Iter 68: Obj = 2547.501235
# Iter 69: Obj = 2547.506502
# Iter 70: Obj = 2547.511551
# Iter 71: Obj = 2547.516389
# Iter 72: Obj = 2547.521024
# Iter 73: Obj = 2547.525464
# Iter 74: Obj = 2547.529715
# Iter 75: Obj = 2547.533786
# Iter 76: Obj = 2547.537682
# Iter 77: Obj = 2547.541411
# Iter 78: Obj = 2547.544979
# Iter 79: Obj = 2547.548392
# Iter 80: Obj = 2547.551656
# Iter 81: Obj = 2547.554778
# Iter 82: Obj = 2547.557762
# Iter 83: Obj = 2547.560615
# Iter 84: Obj = 2547.563341
# Iter 85: Obj = 2547.565945
# Iter 86: Obj = 2547.568434
# Converged in 86 iterations
# Obj=2547.568434
# Running time= 0.020818471908569336

# %%
#Adaptive step size
from proxop import L1Norm, Square

def elastic_net_objective(beta, X, y, lambda_reg, alpha):
    """
    Computes the Elastic Net objective function value.
    """
    n = X.shape[0]
    residual = X @ beta - y
    mse_term = (1 / (2 * n)) * np.dot(residual, residual)
    l1_term = lambda_reg * alpha * np.sum(np.abs(beta))
    l2_term = (lambda_reg * (1 - alpha) / 2) * np.dot(beta, beta)
    return mse_term + l1_term + l2_term

# Sample data
n, d = X.shape

# Parameters
lambda_reg = 0.1  # Regularization strength
alpha = 0.027    # Mixing parameter between L1 and L2
t_init = 1
max_iter = 1000
epsilon = 1e-6

# Initialize parameters
beta = np.ones(d)

# Initialize proximal operators
prox_l1 = L1Norm(lambda_reg * alpha)
prox_l2 = Square()
start_time = time.time()
# Proximal Gradient Descent loop
for i in range(max_iter):
    # Compute the gradient of the MSE term
    gradient = (1 / n) * X.T @ (X @ beta - y)
    eta = backtracking_line_search(X, y, beta, gradient, L,t_init)
    t_init=eta
    beta_prev = beta.copy()

    # Gradient step
    beta_temp = beta - eta * gradient

    # Apply the proximal operator for the squared L2 norm
    beta_temp = prox_l2.prox(beta_temp, gamma=eta * lambda_reg * (1 - alpha))

    # Apply the proximal operator for the L1 norm
    beta = prox_l1.prox(beta_temp, gamma=eta)

    # Compute the objective function value
    obj_value = elastic_net_objective(beta, X, y, lambda_reg, alpha)
    print(f"Iter {i}: Obj = {obj_value:.6f}")

    # Check for convergence
    if abs(elastic_net_objective(beta,X,y,lambda_reg, alpha) - elastic_net_objective(beta_prev,X,y,lambda_reg, alpha))/max(1,abs(elastic_net_objective(beta_prev,X,y,lambda_reg, alpha))) < epsilon:
        print(f"Converged in {i} iterations")
        break
end_time = time.time()

print(f"Obj={elastic_net_objective(beta,X,y,lambda_reg, alpha):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8900.329010
# Iter 1: Obj = 6227.687846
# Iter 2: Obj = 4690.923629
# Iter 3: Obj = 3801.259054
# Iter 4: Obj = 3283.917476
# Iter 5: Obj = 2982.166950
# Iter 6: Obj = 2805.589520
# Iter 7: Obj = 2701.844376
# Iter 8: Obj = 2640.554870
# Iter 9: Obj = 2604.138993
# Iter 10: Obj = 2582.321197
# Iter 11: Obj = 2569.124799
# Iter 12: Obj = 2561.053901
# Iter 13: Obj = 2556.054373
# Iter 14: Obj = 2552.912952
# Iter 15: Obj = 2550.908477
# Iter 16: Obj = 2549.608939
# Iter 17: Obj = 2548.753093
# Iter 18: Obj = 2548.181171
# Iter 19: Obj = 2547.794171
# Iter 20: Obj = 2547.529820
# Iter 21: Obj = 2547.348290
# Iter 22: Obj = 2547.223654
# Iter 23: Obj = 2547.138718
# Iter 24: Obj = 2547.081867
# Iter 25: Obj = 2547.045116
# Iter 26: Obj = 2547.022880
# Iter 27: Obj = 2547.011197
# Iter 28: Obj = 2547.007217
# Iter 29: Obj = 2547.008868
# Converged in 29 iterations
# Obj=2547.008868
# Running time= 0.009501218795776367

# %%
#Fixed step size
from proxop import L1Norm, Square

def elastic_net_objective(beta, X, y, lambda_reg, alpha):
    """
    Computes the Elastic Net objective function value.
    """
    n = X.shape[0]
    residual = X @ beta - y
    mse_term = (1 / (2 * n)) * np.dot(residual, residual)
    l1_term = lambda_reg * alpha * np.sum(np.abs(beta))
    l2_term = (lambda_reg * (1 - alpha) / 2) * np.dot(beta, beta)
    return mse_term + l1_term + l2_term

# Sample data

n, d = X.shape

# Parameters
lambda_reg = 0.1  # Regularization strength
alpha = 0.027      # Mixing parameter between L1 and L2
step_size = 1 / L
max_iter = 1000
epsilon = 1e-6


# Initialize parameters
beta = np.ones(d)
theta = beta.copy()
t = 1

# Initialize proximal operators
prox_l1 = L1Norm(lambda_reg * alpha)
prox_l2 = Square()
start_time = time.time()
# FISTA loop
for i in range(max_iter):
    beta_prev = beta.copy()

    # Compute the gradient of the MSE term
    gradient = (1 / n) * X.T @ (X @ theta - y)

    # Gradient step
    beta_temp = theta - step_size * gradient

    # Apply the proximal operator for the squared L2 norm
    beta_temp = prox_l2.prox(beta_temp, gamma=step_size * lambda_reg * (1 - alpha))

    # Apply the proximal operator for the L1 norm
    beta_next = prox_l1.prox(beta_temp, gamma=step_size)

    # Update the momentum term
    t_next = (1 + np.sqrt(1 + 4 * t ** 2)) / 2
    theta = beta_next + ((t - 1) / t_next) * (beta_next - beta)


    # Compute the objective function value
    obj_value = elastic_net_objective(beta_next, X, y, lambda_reg, alpha)
    print(f"Iter {i}: Obj = {obj_value:.6f}")

    # Check for convergence after minimum iterations
    if abs(elastic_net_objective(beta_next,X,y,lambda_reg, alpha) - elastic_net_objective(beta,X,y,lambda_reg, alpha))/max(1,abs(elastic_net_objective(beta,X,y,lambda_reg, alpha))) < epsilon:
        print(f"Converged in {i} iterations")
        break
    # Update variables
    beta = beta_next
    t = t_next



end_time = time.time()
print(f"Obj={elastic_net_objective(beta,X,y,lambda_reg, alpha):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8463.444028
# Iter 1: Obj = 5752.718214
# Iter 2: Obj = 3960.875754
# Iter 3: Obj = 3022.310708
# Iter 4: Obj = 2648.769991
# Iter 5: Obj = 2552.580542
# Iter 6: Obj = 2548.139555
# Iter 7: Obj = 2554.179981
# Iter 8: Obj = 2552.773951
# Iter 9: Obj = 2548.480998
# Iter 10: Obj = 2546.405508
# Iter 11: Obj = 2547.032077
# Iter 12: Obj = 2548.499384
# Iter 13: Obj = 2549.329800
# Iter 14: Obj = 2549.252880
# Iter 15: Obj = 2548.700204
# Iter 16: Obj = 2548.132466
# Iter 17: Obj = 2547.757056
# Iter 18: Obj = 2547.579484
# Iter 19: Obj = 2547.539748
# Iter 20: Obj = 2547.586600
# Iter 21: Obj = 2547.683768
# Iter 22: Obj = 2547.796887
# Iter 23: Obj = 2547.891971
# Iter 24: Obj = 2547.944644
# Iter 25: Obj = 2547.947435
# Iter 26: Obj = 2547.908478
# Iter 27: Obj = 2547.844121
# Iter 28: Obj = 2547.771160
# Iter 29: Obj = 2547.702205
# Iter 30: Obj = 2547.644430
# Iter 31: Obj = 2547.600305
# Iter 32: Obj = 2547.569032
# Iter 33: Obj = 2547.548025
# Iter 34: Obj = 2547.534212
# Iter 35: Obj = 2547.525007
# Iter 36: Obj = 2547.518826
# Iter 37: Obj = 2547.515143
# Iter 38: Obj = 2547.514184
# Converged in 38 iterations
# Obj=2547.515143
# Running time= 0.005632638931274414

# %%
#Adaptive step size
from proxop import L1Norm, Square

def elastic_net_objective(beta, X, y, lambda_reg, alpha):
    """
    Computes the Elastic Net objective function value.
    """
    n = X.shape[0]
    residual = X @ beta - y
    mse_term = (1 / (2 * n)) * np.dot(residual, residual)
    l1_term = lambda_reg * alpha * np.sum(np.abs(beta))
    l2_term = (lambda_reg * (1 - alpha) / 2) * np.dot(beta, beta)
    return mse_term + l1_term + l2_term

# Sample data

n, d = X.shape

# Parameters
lambda_reg = 0.1  # Regularization strength
alpha = 0.027      # Mixing parameter between L1 and L2
t_init = 1
max_iter = 1000
epsilon = 1e-6


# Initialize parameters
beta = np.ones(d)
theta = beta.copy()
t = 1

# Initialize proximal operators
prox_l1 = L1Norm(lambda_reg * alpha)
prox_l2 = Square()
start_time = time.time()
# FISTA loop
for i in range(max_iter):
    beta_prev = beta.copy()

    # Compute the gradient of the MSE term
    gradient = (1 / n) * X.T @ (X @ theta - y)
    eta = backtracking_line_search(X, y, beta, gradient, L,t_init)
    t_init=eta
    # Gradient step
    beta_temp = theta - eta * gradient

    # Apply the proximal operator for the squared L2 norm
    beta_temp = prox_l2.prox(beta_temp, gamma=eta * lambda_reg * (1 - alpha))

    # Apply the proximal operator for the L1 norm
    beta_next = prox_l1.prox(beta_temp, gamma=eta)

    # Update the momentum term
    t_next = (1 + np.sqrt(1 + 4 * t ** 2)) / 2
    theta = beta_next + ((t - 1) / t_next) * (beta_next - beta)


    # Compute the objective function value
    obj_value = elastic_net_objective(beta_next, X, y, lambda_reg, alpha)
    print(f"Iter {i}: Obj = {obj_value:.6f}")

    # Check for convergence after minimum iterations
    if abs(elastic_net_objective(beta_next,X,y,lambda_reg, alpha) - elastic_net_objective(beta,X,y,lambda_reg, alpha))/max(1,abs(elastic_net_objective(beta,X,y,lambda_reg, alpha))) < epsilon:
        print(f"Converged in {i} iterations")
        break
    # Update variables
    beta = beta_next
    t = t_next


end_time = time.time()

print(f"Obj={elastic_net_objective(beta,X,y,lambda_reg, alpha):.6f}")
print(f"Running time= {end_time-start_time}")
# Out:
# Iter 0: Obj = 8900.329010
# Iter 1: Obj = 6227.687846
# Iter 2: Obj = 4331.983719
# Iter 3: Obj = 3237.150036
# Iter 4: Obj = 2735.897466
# Iter 5: Obj = 2571.172670
# Iter 6: Obj = 2545.999117
# Iter 7: Obj = 2553.440199
# Iter 8: Obj = 2556.277940
# Iter 9: Obj = 2552.259223
# Iter 10: Obj = 2547.786516
# Iter 11: Obj = 2546.354045
# Iter 12: Obj = 2547.404297
# Iter 13: Obj = 2548.954874
# Iter 14: Obj = 2549.710683
# Iter 15: Obj = 2549.524742
# Iter 16: Obj = 2548.865005
# Iter 17: Obj = 2548.203640
# Iter 18: Obj = 2547.757698
# Iter 19: Obj = 2547.533937
# Iter 20: Obj = 2547.464779
# Iter 21: Obj = 2547.492715
# Iter 22: Obj = 2547.582801
# Iter 23: Obj = 2547.705466
# Iter 24: Obj = 2547.827080
# Iter 25: Obj = 2547.916147
# Iter 26: Obj = 2547.954193
# Iter 27: Obj = 2547.940313
# Iter 28: Obj = 2547.887180
# Iter 29: Obj = 2547.812973
# Iter 30: Obj = 2547.734399
# Iter 31: Obj = 2547.663175
# Iter 32: Obj = 2547.605510
# Iter 33: Obj = 2547.563117
# Iter 34: Obj = 2547.534631
# Iter 35: Obj = 2547.516967
# Iter 36: Obj = 2547.506531
# Iter 37: Obj = 2547.500196
# Iter 38: Obj = 2547.495908
# Iter 39: Obj = 2547.492848
# Iter 40: Obj = 2547.491200
# Converged in 40 iterations
# Obj=2547.492848
# Running time= 0.00988149642944336
